# %%
import mysql.connector
import pandas as pd

df = pd.read_csv("./NY_Acc.csv")
df.head()
# Out:
#    Unnamed: 0  Start_Time  Start_Lat  Start_Lng      City
# 0       31580        2016  40.850020 -73.943990  New York
# 1       31625        2016  40.771460 -73.946580  New York
# 2       31710        2016  40.762979 -73.973938  New York
# 3       31901        2016  40.744340 -73.971240  New York
# 4       32073        2016  40.710680 -74.002720  New York

# %%
remote = mysql.connector.connect(
    host = "database-2.c03xmansdwhk.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "Naverinough1!",
    database = "amrbase"
)

# %%
cur = remote.cursor(buffered=True)

# %%
cur.execute("CREATE TABLE NY_Acc (None int, Start_Time int, Start_Lat float, Start_Lng float, City varchar(16))")

# %%
sql = "INSERT INTO NY_Acc VALUES (%s, %s, %s, %s, %s)"

for i, row in df.iterrows():
    cur.execute(sql, tuple(row))
    print(tuple(row))
    remote.commit()
cur.execute("SELECT * FROM NY_Acc")
# Out:
# (31580, 2016, 40.85002, -73.94399, 'New York')
# (31625, 2016, 40.77146, -73.94658000000003, 'New York')
# (31710, 2016, 40.762979, -73.973938, 'New York')
# (31901, 2016, 40.74434, -73.97124000000002, 'New York')
# (32073, 2016, 40.71068, -74.00272, 'New York')
# (32312, 2016, 40.83873, -73.93327, 'New York')
# (32416, 2016, 40.71643, -73.97559, 'New York')
# (32629, 2016, 40.762057, -74.00133199999998, 'New York')
# (32630, 2016, 40.76072, -74.00206999999997, 'New York')
# (33622, 2016, 40.73746, -73.97445, 'New York')
# (33781, 2016, 40.793019, -73.923891, 'New York')
# (33828, 2016, 40.798993, -73.924353, 'New York')
# (33869, 2016, 40.756474, -73.953517, 'New York')
# (34083, 2016, 40.757391, -73.982249, 'New York')
# (34190, 2016, 40.74434, -73.97124000000002, 'New York')
# (34409, 2016, 40.78491, -73.94109, 'New York')
# (34513, 2016, 40.85005, -73.94481, 'New York')
# (34534, 2016, 40.78128, -73.9441, 'New York')
# (34620, 2016, 40.75776, -73.99685, 'New York')
# ...

# %%
result = cur.fetchall()
for row in result:
    print(row)
# Out:
# (31580, 2016, 40.85, -73.944, 'New York')
# (31580, 2016, 40.85, -73.944, 'New York')
# (31625, 2016, 40.7715, -73.9466, 'New York')
# (31710, 2016, 40.763, -73.9739, 'New York')
# (31901, 2016, 40.7443, -73.9712, 'New York')
# (32073, 2016, 40.7107, -74.0027, 'New York')
# (32312, 2016, 40.8387, -73.9333, 'New York')
# (32416, 2016, 40.7164, -73.9756, 'New York')
# (32629, 2016, 40.7621, -74.0013, 'New York')
# (32630, 2016, 40.7607, -74.0021, 'New York')
# (33622, 2016, 40.7375, -73.9744, 'New York')
# (33781, 2016, 40.793, -73.9239, 'New York')
# (33828, 2016, 40.799, -73.9244, 'New York')
# (33869, 2016, 40.7565, -73.9535, 'New York')
# (34083, 2016, 40.7574, -73.9822, 'New York')
# (34190, 2016, 40.7443, -73.9712, 'New York')
# (34409, 2016, 40.7849, -73.9411, 'New York')
# (34513, 2016, 40.8501, -73.9448, 'New York')
# (34534, 2016, 40.7813, -73.9441, 'New York')
# (34620, 2016, 40.7578, -73.9968, 'New York')
# (34681, 2016, 40.7578, -73.9968, 'New York')
# ...

# %%
df = pd.DataFrame(result)
df
# Out:
#             0     1        2        3         4
# 0       31580  2016  40.8500 -73.9440  New York
# 1       31580  2016  40.8500 -73.9440  New York
# 2       31625  2016  40.7715 -73.9466  New York
# 3       31710  2016  40.7630 -73.9739  New York
# 4       31901  2016  40.7443 -73.9712  New York
# ...       ...   ...      ...      ...       ...
# 7064  2843385  2019  40.7375 -73.9743  New York
# 7065  2843916  2019  40.8500 -73.9440  New York
# 7066  2844444  2019  40.7604 -73.9629  New York
# 7067  2844464  2019  40.7481 -73.9679  New York
# 7068  2844953  2019  40.8500 -73.9440  New York
#
# [7069 rows x 5 columns]

# %%
cur.execute("SELECT Start_Time, Start_Lat, Start_Lng, City FROM NY_Acc WHERE Start_Time = 2021")

result = cur.fetchall()
for row in result:
    print(row)
# Out:
# (2021, 40.846, -73.9302, 'New York')
# (2021, 40.7519, -73.9996, 'New York')
# (2021, 40.7698, -73.9948, 'New York')
# (2021, 40.8516, -73.952, 'New York')
# (2021, 40.8464, -73.9311, 'New York')
# (2021, 40.849, -73.9391, 'New York')
# (2021, 40.8461, -73.9304, 'New York')
# (2021, 40.811, -73.9669, 'New York')
# (2021, 40.811, -73.9669, 'New York')
# (2021, 40.818, -73.9615, 'New York')
# (2021, 40.8504, -73.9469, 'New York')
# (2021, 40.8488, -73.9386, 'New York')
# (2021, 40.8029, -73.9305, 'New York')
# (2021, 40.8019, -73.9302, 'New York')
# (2021, 40.714, -73.9729, 'New York')
# (2021, 40.8486, -73.9375, 'New York')
# (2021, 40.8388, -73.9332, 'New York')
# (2021, 40.8461, -73.9304, 'New York')
# (2021, 40.8472, -73.9335, 'New York')
# (2021, 40.8066, -73.9334, 'New York')
# (2021, 40.7607, -74.0056, 'New York')
# (2021, 40.7097, -73.992, 'New York')
# (2021, 40.8484, -73.937, 'New York')
# (2021, 40.8225, -73.9578, 'New York')
# (2021, 40.823, -73.9343, 'New York')
# ...

# %%
df = pd.DataFrame(result)

# %%
df.to_csv('./NY_2021_Acc.csv', index = None)
