# %%
import pandas as pd

# %%
import folium

# %%
location = pd.read_csv('./metro_2022_10_location.csv', encoding='EUC-KR')
location = location.drop(['사용월',  '출근시간(04~09) 승차', '출근시간(07~10) 하차', '퇴근시간(16~20) 승차', '퇴근시간(17~21) 하차'
                         , '점심시간', '저녁시간', '늦은시간퇴근(20~02) 승차', '총 승차 인원',  '총 하차 인원', '월', '연도'], axis=1)
location.rename(columns={location.columns[0]: "0"}, inplace=True)
location = location.drop(['0'], axis=1)
location
# Out:
#        호선명      지하철역        lat         lng
# 0      9호선        흑석  37.508770  126.963708
# 1      경의선     효창공원앞  37.539261  126.961351
# 2      6호선     효창공원앞  37.539261  126.961351
# 3      4호선        회현  37.558514  126.978246
# 4      경원선        회룡  37.724846  127.046895
# ..     ...       ...        ...         ...
# 445    7호선   가산디지털단지  37.481072  126.882343
# 446    경부선   가산디지털단지  37.481072  126.882343
# 447    8호선      가락시장  37.492522  127.118234
# 448    3호선      가락시장  37.492522  127.118234
# 449  우이신설선  4.19민주묘지  37.649500  127.013700
#
# [450 rows x 4 columns]

# %%
list_df = pd.DataFrame(df['호선명'].value_counts())
list_df = list_df.reset_index()
list_df_list = list_df['index'].to_list()
list_df_list
# Out:
# ['5호선',
#  '2호선',
#  '7호선',
#  '6호선',
#  '3호선',
#  '4호선',
#  '9호선',
#  '경의선',
#  '경원선',
#  '8호선',
#  '분당선',
#  '경부선',
#  '우이신설선',
#  '9호선2~3단계',
#  '신림선',
#  '1호선',
#  '일산선',
#  '경인선',
#  '중앙선',
#  '경춘선',
#  '공항철도 1호선',
#  '과천선']

# %%
len(list_df_list)
# Out:
# 22

# %%
sub_list = []
for i in list_df_list:
    sub_list.append(location[location['호선명'].isin([i])])
sub_list[0]
# Out:
#      호선명       지하철역        lat         lng
# 9    5호선         화곡  37.541513  126.840461
# 17   5호선         행당  37.557322  127.029476
# 28   5호선       하남풍산  37.552200  127.203900
# 29   5호선       하남시청  37.541800  127.206600
# 37   5호선        충정로  37.559973  126.963672
# 46   5호선         청구  37.560245  127.013828
# 49   5호선         천호  37.538397  127.123572
# 70   5호선       종로3가  37.571607  126.991806
# 77   5호선        장한평  37.561440  127.064623
# 96   5호선      을지로4가  37.566941  126.998079
# 106  5호선        우장산  37.548768  126.836318
# 112  5호선        왕십리  37.561533  127.037732
# 115  5호선      올림픽공원  37.516078  127.130848
# 121  5호선        오목교  37.524496  126.875181
# 123  5호선         오금  37.502162  127.128111
# 125  5호선      영등포시장  37.522669  126.905139
# 127  5호선      영등포구청  37.524970  126.895951
# 135  5호선        여의도  37.521624  126.924191
# 137  5호선       여의나루  37.527098  126.932901
# 148  5호선        애오개  37.553736  126.956820
# 155  5호선        아차산  37.551691  127.089761
# 163  5호선         신정  37.524997  126.856191
# 186  5호선         신길  37.517122  126.917169
# 187  5호선        신금호  37.554548  127.020331
# 200  5호선         송정  37.561184  126.811973
# 232  5호선        서대문  37.565773  126.966641
# 237  5호선        상일동  37.556712  127.166417
# 280  5호선         방화  37.577446  126.812741
# 282  5호선         방이  37.508857  127.126133
# 284  5호선         발산  37.558598  126.837668
# 288  5호선         미사  37.563100  127.193000
# 293  5호선         목동  37.526065  126.864931
# 296  5호선         명일  37.551370  127.143999
# 305  5호선         마포  37.539574  126.945932
# 306  5호선         마천  37.494990  127.152781
# 307  5호선         마장  37.566100  127.042973
# 312  5호선         마곡  37.560183  126.825448
# 320  5호선        둔촌동  37.527788  127.136248
# 326  5호선  동대문역사문화공원  37.565138  127.007896
# 357  5호선        답십리  37.566747  127.052704
# 378  5호선        까치산  37.531768  126.846683
# 381  5호선       김포공항  37.562434  126.801058
# 383  5호선         길동  37.537801  127.140004
# 387  5호선       굽은다리  37.545477  127.142853
# 389  5호선         군자  37.557121  127.079542
# 403  5호선        광화문  37.571026  126.976669
# 406  5호선        광나루  37.545303  127.103570
# 411  5호선         공덕  37.544018  126.951592
# 420  5호선         고덕  37.555004  127.154151
# 426  5호선         거여  37.493105  127.144150
# 427  5호선        개화산  37.572399  126.806171
# 431  5호선         개롱  37.498079  127.134820
# 432  5호선         강일  37.557400  127.175400
# 436  5호선         강동  37.535804  127.132481

# %%
for i in range(22):
    sub_list[i] = sub_list[i].reset_index()
    sub_list[i] = sub_list[i].reset_index()
sub_list[0]
# Out:
#     level_0  index  호선명       지하철역        lat         lng
# 0         0      9  5호선         화곡  37.541513  126.840461
# 1         1     17  5호선         행당  37.557322  127.029476
# 2         2     28  5호선       하남풍산  37.552200  127.203900
# 3         3     29  5호선       하남시청  37.541800  127.206600
# 4         4     37  5호선        충정로  37.559973  126.963672
# 5         5     46  5호선         청구  37.560245  127.013828
# 6         6     49  5호선         천호  37.538397  127.123572
# 7         7     70  5호선       종로3가  37.571607  126.991806
# 8         8     77  5호선        장한평  37.561440  127.064623
# 9         9     96  5호선      을지로4가  37.566941  126.998079
# 10       10    106  5호선        우장산  37.548768  126.836318
# 11       11    112  5호선        왕십리  37.561533  127.037732
# 12       12    115  5호선      올림픽공원  37.516078  127.130848
# 13       13    121  5호선        오목교  37.524496  126.875181
# 14       14    123  5호선         오금  37.502162  127.128111
# 15       15    125  5호선      영등포시장  37.522669  126.905139
# 16       16    127  5호선      영등포구청  37.524970  126.895951
# 17       17    135  5호선        여의도  37.521624  126.924191
# 18       18    137  5호선       여의나루  37.527098  126.932901
# 19       19    148  5호선        애오개  37.553736  126.956820
# 20       20    155  5호선        아차산  37.551691  127.089761
# 21       21    163  5호선         신정  37.524997  126.856191
# 22       22    186  5호선         신길  37.517122  126.917169
# 23       23    187  5호선        신금호  37.554548  127.020331
# 24       24    200  5호선         송정  37.561184  126.811973
# 25       25    232  5호선        서대문  37.565773  126.966641
# 26       26    237  5호선        상일동  37.556712  127.166417
# 27       27    280  5호선         방화  37.577446  126.812741
# 28       28    282  5호선         방이  37.508857  127.126133
# 29       29    284  5호선         발산  37.558598  126.837668
# 30       30    288  5호선         미사  37.563100  127.193000
# 31       31    293  5호선         목동  37.526065  126.864931
# 32       32    296  5호선         명일  37.551370  127.143999
# 33       33    305  5호선         마포  37.539574  126.945932
# 34       34    306  5호선         마천  37.494990  127.152781
# 35       35    307  5호선         마장  37.566100  127.042973
# 36       36    312  5호선         마곡  37.560183  126.825448
# 37       37    320  5호선        둔촌동  37.527788  127.136248
# 38       38    326  5호선  동대문역사문화공원  37.565138  127.007896
# 39       39    357  5호선        답십리  37.566747  127.052704
# 40       40    378  5호선        까치산  37.531768  126.846683
# 41       41    381  5호선       김포공항  37.562434  126.801058
# 42       42    383  5호선         길동  37.537801  127.140004
# 43       43    387  5호선       굽은다리  37.545477  127.142853
# 44       44    389  5호선         군자  37.557121  127.079542
# 45       45    403  5호선        광화문  37.571026  126.976669
# 46       46    406  5호선        광나루  37.545303  127.103570
# 47       47    411  5호선         공덕  37.544018  126.951592
# 48       48    420  5호선         고덕  37.555004  127.154151
# 49       49    426  5호선         거여  37.493105  127.144150
# 50       50    427  5호선        개화산  37.572399  126.806171
# 51       51    431  5호선         개롱  37.498079  127.134820
# 52       52    432  5호선         강일  37.557400  127.175400
# 53       53    436  5호선         강동  37.535804  127.132481

# %%
color_list = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightgreen', 'gray' ,'beige', 'darkblue', 'darkgreen', 'cadetblue', 
 'darkpurple', 'white', 'lightred', 'pink' ,'lightblue', 'lightgreen', 'gray', 'black', 'lightgray', 'darkred']
len(color_list)
# Out:
# 22

# %%
my_map = folium.Map(location=[37.5502, 126.982], zoom_start=11, title="Stamen Toner")

for each in range(len(sub_list)):
    for i in range(len(sub_list[each])):
        if  (i+1) != len(sub_list[each]):
            start =  sub_list[each]['lat'][i], sub_list[each]['lng'][i] 
            end = sub_list[each]['lat'][i+1], sub_list[each]['lng'][i+1]
            
            location_data = [start, end]
            folium.PolyLine(locations=location_data, tooltip='Polyline', color=color_list[each]).add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b447e9fb8883f507924a039393dfa36c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b447e9fb8883f507924a039393dfa36c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b447e9fb8883f507924a039393dfa36c = L.map(
#                 &quot;map_b447e9fb8883f507924a039393dfa36c&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Stamen Toner&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28c3317e4cdecbcf25a0f1b176e21fb0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b447e9fb8883f507924a039393dfa36c);
#
#
#             var poly_line_2568d2623978d6ba9dff4a7dcecb92a1 = L.polyline(
#                 [[37.541513, 126.840461], [37.557322, 127.029476]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b447e9fb8883f507924a039393dfa36c);
#
#
#             poly_line_2568d2623978d6ba9dff4a7dcecb92a1.bindTooltip(
#                 `&lt;div&gt;
#                      Polyline
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_a430f882cd76088455985450ba069aef = L.polyline(
#                 [[37.557322, 127.029476], [37.5522, 127.2039]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b447e9fb8883f507924a039393dfa36c);
#
#
#             poly_line_a430f882cd76088455985450ba069aef.bindTooltip(
#                 `&lt;div&gt;
#                      Polyline
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_040ec03d3b657e1be88f1e26a7439e8d = L.polyline(
#                 [[37.5522, 127.2039], [37.5418, 127.2066]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b447e9fb8883f507924a039393dfa36c);
#
#
#             poly_line_040ec03d3b657e1be88f1e26a7439e8d.bindTooltip(
#                 `&lt;div&gt;
#                      Polyline
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_b1231481aab367544e1306865c13af73 = L.polyline(
#                 [[37.5418, 127.2066], [37.559973, 126.963672]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b447e9fb8883f507924a039393dfa36c);
#
#
#             poly_line_b1231481aab367544e1306865c13af73.bindTooltip(
#                 `&lt;div&gt;
#                      Polyline
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_40efd5454d9e341bb182cee4e0e00157 = L.polyline(
#                 [[37.559973, 126.963672], [37.560245, 127.013828]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fill

# %%
from haversine import haversine

# %%
sub_list_sort = []
for i in list_df_list:
    sub_list_sort.append(sub_list[0][sub_list[0]['level_0'].isin([999999])])
sub_list_sort[0]
# Out:
# Empty DataFrame
# Columns: [level_0, index, 호선명, 지하철역, lat, lng]
# Index: []

# %%
for i in range(len(sub_list)):
    su = 0
    su_list = []
    su_list.append(0)
    count = 0

    sel = 1

    while True:
        list_temp = []
        start =  [sub_list[i]['lat'][su], sub_list[i]['lng'][su]]
        for j in range(len(sub_list[i])):
            if not(j in su_list):
                end =  [sub_list[i]['lat'][j], sub_list[i]['lng'][j]]
                a = haversine(start, end, unit = 'km')
                list_temp.append(a)
            else:
                list_temp.append(10)
        

        if min(list_temp) > 3:
            su = 0
            sel = 0
            count = count + 1 
            # 까치산 처럼 갈라지는 곳은 대응못함

        else:
            tmp = min(list_temp)
            index = list_temp.index(tmp)

            if sel == 1:
                sub_list_temp = sub_list[i][sub_list[i]['level_0'].isin([index])]
                sub_list_sort[i] = pd.concat([sub_list_sort[i] , sub_list_temp])

            elif sel == 0:
                sub_list_temp = sub_list[i][sub_list[i]['level_0'].isin([index])]
                sub_list_sort[i] = pd.concat([ sub_list_temp, sub_list_sort[i]])

            su_list.append(index)
            su = index
            
        if count == 2:
            break

        if len(su_list) == len(sub_list[i]):
            break

# %%
sub_list_sort[0]
# Out:
#     level_0  index  호선명       지하철역        lat         lng
# 3         3     29  5호선       하남시청  37.541800  127.206600
# 2         2     28  5호선       하남풍산  37.552200  127.203900
# 30       30    288  5호선         미사  37.563100  127.193000
# 52       52    432  5호선         강일  37.557400  127.175400
# 26       26    237  5호선        상일동  37.556712  127.166417
# 48       48    420  5호선         고덕  37.555004  127.154151
# 32       32    296  5호선         명일  37.551370  127.143999
# 43       43    387  5호선       굽은다리  37.545477  127.142853
# 42       42    383  5호선         길동  37.537801  127.140004
# 53       53    436  5호선         강동  37.535804  127.132481
# 6         6     49  5호선         천호  37.538397  127.123572
# 46       46    406  5호선        광나루  37.545303  127.103570
# 20       20    155  5호선        아차산  37.551691  127.089761
# 44       44    389  5호선         군자  37.557121  127.079542
# 8         8     77  5호선        장한평  37.561440  127.064623
# 39       39    357  5호선        답십리  37.566747  127.052704
# 35       35    307  5호선         마장  37.566100  127.042973
# 11       11    112  5호선        왕십리  37.561533  127.037732
# 1         1     17  5호선         행당  37.557322  127.029476
# 23       23    187  5호선        신금호  37.554548  127.020331
# 5         5     46  5호선         청구  37.560245  127.013828
# 38       38    326  5호선  동대문역사문화공원  37.565138  127.007896
# 9         9     96  5호선      을지로4가  37.566941  126.998079
# 7         7     70  5호선       종로3가  37.571607  126.991806
# 45       45    403  5호선        광화문  37.571026  126.976669
# 25       25    232  5호선        서대문  37.565773  126.966641
# 4         4     37  5호선        충정로  37.559973  126.963672
# 19       19    148  5호선        애오개  37.553736  126.956820
# 47       47    411  5호선         공덕  37.544018  126.951592
# 33       33    305  5호선         마포  37.539574  126.945932
# 18       18    137  5호선       여의나루  37.527098  126.932901
# 17       17    135  5호선        여의도  37.521624  126.924191
# 22       22    186  5호선         신길  37.517122  126.917169
# 15       15    125  5호선      영등포시장  37.522669  126.905139
# 16       16    127  5호선      영등포구청  37.524970  126.895951
# 13       13    121  5호선        오목교  37.524496  126.875181
# 31       31    293  5호선         목동  37.526065  126.864931
# 21       21    163  5호선         신정  37.524997  126.856191
# 40       40    378  5호선        까치산  37.531768  126.846683
# 10       10    106  5호선        우장산  37.548768  126.836318
# 29       29    284  5호선         발산  37.558598  126.837668
# 36       36    312  5호선         마곡  37.560183  126.825448
# 24       24    200  5호선         송정  37.561184  126.811973
# 41       41    381  5호선       김포공항  37.562434  126.801058
# 50       50    427  5호선        개화산  37.572399  126.806171
# 27       27    280  5호선         방화  37.577446  126.812741

# %%
for i in range(22):
    sub_list_sort[i] = sub_list_sort[i].drop(['level_0', 'index'], axis=1)
    sub_list_sort[i] = sub_list_sort[i].reset_index()
    sub_list_sort[i] = sub_list_sort[i].reset_index()
sub_list_sort[0]
# Out:
#     level_0  index  호선명       지하철역        lat         lng
# 0         0      3  5호선       하남시청  37.541800  127.206600
# 1         1      2  5호선       하남풍산  37.552200  127.203900
# 2         2     30  5호선         미사  37.563100  127.193000
# 3         3     52  5호선         강일  37.557400  127.175400
# 4         4     26  5호선        상일동  37.556712  127.166417
# 5         5     48  5호선         고덕  37.555004  127.154151
# 6         6     32  5호선         명일  37.551370  127.143999
# 7         7     43  5호선       굽은다리  37.545477  127.142853
# 8         8     42  5호선         길동  37.537801  127.140004
# 9         9     53  5호선         강동  37.535804  127.132481
# 10       10      6  5호선         천호  37.538397  127.123572
# 11       11     46  5호선        광나루  37.545303  127.103570
# 12       12     20  5호선        아차산  37.551691  127.089761
# 13       13     44  5호선         군자  37.557121  127.079542
# 14       14      8  5호선        장한평  37.561440  127.064623
# 15       15     39  5호선        답십리  37.566747  127.052704
# 16       16     35  5호선         마장  37.566100  127.042973
# 17       17     11  5호선        왕십리  37.561533  127.037732
# 18       18      1  5호선         행당  37.557322  127.029476
# 19       19     23  5호선        신금호  37.554548  127.020331
# 20       20      5  5호선         청구  37.560245  127.013828
# 21       21     38  5호선  동대문역사문화공원  37.565138  127.007896
# 22       22      9  5호선      을지로4가  37.566941  126.998079
# 23       23      7  5호선       종로3가  37.571607  126.991806
# 24       24     45  5호선        광화문  37.571026  126.976669
# 25       25     25  5호선        서대문  37.565773  126.966641
# 26       26      4  5호선        충정로  37.559973  126.963672
# 27       27     19  5호선        애오개  37.553736  126.956820
# 28       28     47  5호선         공덕  37.544018  126.951592
# 29       29     33  5호선         마포  37.539574  126.945932
# 30       30     18  5호선       여의나루  37.527098  126.932901
# 31       31     17  5호선        여의도  37.521624  126.924191
# 32       32     22  5호선         신길  37.517122  126.917169
# 33       33     15  5호선      영등포시장  37.522669  126.905139
# 34       34     16  5호선      영등포구청  37.524970  126.895951
# 35       35     13  5호선        오목교  37.524496  126.875181
# 36       36     31  5호선         목동  37.526065  126.864931
# 37       37     21  5호선         신정  37.524997  126.856191
# 38       38     40  5호선        까치산  37.531768  126.846683
# 39       39     10  5호선        우장산  37.548768  126.836318
# 40       40     29  5호선         발산  37.558598  126.837668
# 41       41     36  5호선         마곡  37.560183  126.825448
# 42       42     24  5호선         송정  37.561184  126.811973
# 43       43     41  5호선       김포공항  37.562434  126.801058
# 44       44     50  5호선        개화산  37.572399  126.806171
# 45       45     27  5호선         방화  37.577446  126.812741

# %%
sub_list_sort[6]
# Out:
#     level_0  index  호선명   지하철역        lat         lng
# 0         0      8  9호선    신논현  37.504598  127.025060
# 1         1     11  9호선     사평  37.504206  127.015259
# 2         2     22  9호선  고속터미널  37.504810  127.004943
# 3         3      6  9호선    신반포  37.503415  126.995925
# 4         4     20  9호선    구반포  37.501364  126.987332
# 5         5     14  9호선     동작  37.502971  126.979306
# 6         6     17  9호선     노들  37.512887  126.953222
# 7         7     16  9호선    노량진  37.514219  126.942454
# 8         8     10  9호선     샛강  37.517274  126.928422
# 9         9      3  9호선    여의도  37.521624  126.924191
# 10       10     19  9호선  국회의사당  37.528105  126.917874
# 11       11     15  9호선     당산  37.534380  126.902281
# 12       12      9  9호선    선유도  37.538020  126.893525
# 13       13      7  9호선    신목동  37.544277  126.883080
# 14       14      2  9호선     염창  37.546936  126.874916
# 15       15     13  9호선     등촌  37.550632  126.865689
# 16       16      1  9호선     증미  37.557402  126.861939
# 17       17     24  9호선     가양  37.561391  126.854456
# 18       18      4  9호선   양천향교  37.568381  126.841333
# 19       19     12  9호선   마곡나루  37.567336  126.829497
# 20       20      5  9호선    신방화  37.567532  126.816601
# 21       21     21  9호선   공항시장  37.563726  126.810678
# 22       22     18  9호선   김포공항  37.562434  126.801058
# 23       23     23  9호선     개화  37.578608  126.798153

# %%
my_map = folium.Map(location=[37.5502, 126.982], zoom_start=11, title="Stamen Toner")

for each in range(len(sub_list_sort)):
    for i in range(len(sub_list_sort[each])):
        if  (i+1) != len(sub_list_sort[each]):
            start =  sub_list_sort[each]['lat'][i], sub_list_sort[each]['lng'][i] 
            end = sub_list_sort[each]['lat'][i+1], sub_list_sort[each]['lng'][i+1]
            
            
            location_data = [start, end]
            folium.PolyLine(locations=location_data, tooltip='Polyline', color=color_list[each]).add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc7f555e46d465012e3820c7ff54ba8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc7f555e46d465012e3820c7ff54ba8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cc7f555e46d465012e3820c7ff54ba8e = L.map(
#                 &quot;map_cc7f555e46d465012e3820c7ff54ba8e&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Stamen Toner&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70f2f91172b8592978d9ab0892306708 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cc7f555e46d465012e3820c7ff54ba8e);
#
#
#             var poly_line_0179c4017bb070083d5df29a96aabe2d = L.polyline(
#                 [[37.5418, 127.2066], [37.5522, 127.2039]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc7f555e46d465012e3820c7ff54ba8e);
#
#
#             poly_line_0179c4017bb070083d5df29a96aabe2d.bindTooltip(
#                 `&lt;div&gt;
#                      Polyline
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_90450f1445b603e52472320643b2c232 = L.polyline(
#                 [[37.5522, 127.2039], [37.5631, 127.193]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc7f555e46d465012e3820c7ff54ba8e);
#
#
#             poly_line_90450f1445b603e52472320643b2c232.bindTooltip(
#                 `&lt;div&gt;
#                      Polyline
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_c81fdf173bffa57c5801dd746a2e440e = L.polyline(
#                 [[37.5631, 127.193], [37.5574, 127.1754]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc7f555e46d465012e3820c7ff54ba8e);
#
#
#             poly_line_c81fdf173bffa57c5801dd746a2e440e.bindTooltip(
#                 `&lt;div&gt;
#                      Polyline
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_07730fa53f646fd572814d63fef23400 = L.polyline(
#                 [[37.5574, 127.1754], [37.556712, 127.166417]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc7f555e46d465012e3820c7ff54ba8e);
#
#
#             poly_line_07730fa53f646fd572814d63fef23400.bindTooltip(
#                 `&lt;div&gt;
#                      Polyline
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_ab65ad008fa0f16bcce359c518438d98 = L.polyline(
#                 [[37.556712, 127.166417], [37.555004, 127.154151]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &q

# %%
color_list[6]
# Out:
# 'lightgreen'
