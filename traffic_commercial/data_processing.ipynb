# %%
import pandas as pd

# %%
seoul_bus_stop_commute = pd.read_csv('./seoul_bus_commute.csv', encoding = 'EUC-KR')
seoul_bus_stop_commute
# Out:
# /tmp/ipykernel_8677/184622970.py:1: DtypeWarning: Columns (4,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   seoul_bus_stop_commute = pd.read_csv('./seoul_bus_commute.csv', encoding = 'EUC-KR')
#           사용년월  노선번호                    노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0       202210   741      741번(진관차고지~헌인릉입구)  100000001       1001
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)  100000001       1001
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)  100000001       1001
# 3       202210   470       470번(상암차고지~안골마을)  100000001       1001
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  100000002       1002
# ...        ...   ...                    ...        ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)  104000098       5191
# 639996  202106  2415         2415번(자양동~대치동)  104000098       5191
# 639997  202106  2221         2221번(자양동~신설동)  104000098       5191
# 639998  202106  2412      2412번(성수동~세곡동사거리)  104000098       5191
# 639999  202106  광진05       광진05(신자초등학교~강변역)  104000100       5193
#
#                         역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0           종로2가사거리(00077)        122         85        95       123  ...
# 1           종로2가사거리(00089)          0          0         0         0  ...
# 2           종로2가사거리(00032)          6          5       319       232  ...
# 3           종로2가사거리(00067)         59         54         5         3  ...
# 4       창경궁.서울대학교병원(00024)          0          0         0         0  ...
# ...                    ...        ...        ...       ...       ...  ...
# 639995           국민은행자양지점앞          0          0         0         0  ...
# 639996           국민은행자양지점앞          0          0         0         0  ...
# 639997           국민은행자양지점앞          0          0         0         0  ...
# 639998           국민은행자양지점앞          0          0         0         0  ...
# 639999              자양아파트앞          0          0         0         0  ...
#
#         20시하차총승객수  21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  \
# 0             212        234        139        207        177        199
# 1               0          0          0          0          0          0
# 2               0          0          0          0          0          0
# 3             243        320        206        290        229        238
# 4              49         62         83         37         41         31
# ...           ...        ...        ...        ...        ...        ...
# 639995        996        174        847        129        914         29
# 639996         17        192         18        235         21         32
# 639997          8        376          9        337         10        100
# 639998        376        147        365        187        533          3
# 639999        413        217        382        140        452         56
#
#         23시하차총승객수  교통수단타입코드  교통수단타입명      등록일자
# 0             134        10   서울간선버스  20221103
# 1               0        51   서울심야버스  20221103
# 2               0        51   서울심야버스  20221103
# 3             143        10   서울간선버스  20221103
# 4              20        10   서울간선버스  20221103
# ...           ...       ...      ...       ...
# 639995        373         0      NaN  20210703
# 639996          4         0      NaN  20210703
# 639997          2         0      NaN  20210703
# 639998         34         0      NaN  20210703
# 639999        154         0      NaN  20210703
#
# [640000 rows x 57 columns]

# %%
seoul_bus_stop_commute = seoul_bus_stop_commute.drop(['표준버스정류장ID', '버스정류장ARS번호', '등록일자'], axis = 1 )
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  20시승차총승객수  \
# 0              85        95       123         0         0  ...        308
# 1               0         0         0        87        73  ...          0
# 2               5       319       232       141       155  ...          0
# 3              54         5         3         0         0  ...        380
# 4               0         0         0         0         0  ...        289
# ...           ...       ...       ...       ...       ...  ...        ...
# 639995          0         0         0         0         0  ...        174
# 639996          0         0         0         0         0  ...        244
# 639997          0         0         0         0         0  ...        369
# 639998          0         0         0         0         0  ...        276
# 639999          0         0         0         0         0  ...        223
#
#         20시하차총승객수  21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  \
# 0             212        234        139        207        177        199
# 1               0          0          0          0          0          0
# 2               0          0          0          0          0          0
# 3             243        320        206        290        229        238
# 4              49         62         83         37         41         31
# ...           ...        ...        ...        ...        ...        ...
# 639995        996        174        847        129        914         29
# 639996         17        192         18        235         21         32
# 639997          8        376          9        337         10        100
# 639998        376        147        365        187        533          3
# 639999        413        217        382        140        452         56
#
#         23시하차총승객수  교통수단타입코드  교통수단타입명
# 0             134        10   서울간선버스
# 1               0        51   서울심야버스
# 2               0        51   서울심야버스
# 3             143        10   서울간선버스
# 4              20        10   서울간선버스
# ...           ...       ...      ...
# 639995        373         0      NaN
# 639996          4         0      NaN
# 639997          2         0      NaN
# 639998         34         0      NaN
# 639999        154         0      NaN
#
# [640000 rows x 54 columns]

# %%
seoul_bus_stop_commute['출근시간(04~09) 승차'] = seoul_bus_stop_commute['4시승차총승객수'] + seoul_bus_stop_commute['5시승차총승객수'] + \
                                            seoul_bus_stop_commute['6시승차총승객수'] + seoul_bus_stop_commute['7시승차총승객수']  + \
                                            seoul_bus_stop_commute['8시승차총승객수'] + seoul_bus_stop_commute['9시승차총승객수']
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  20시하차총승객수  \
# 0              85        95       123         0         0  ...        212
# 1               0         0         0        87        73  ...          0
# 2               5       319       232       141       155  ...          0
# 3              54         5         3         0         0  ...        243
# 4               0         0         0         0         0  ...         49
# ...           ...       ...       ...       ...       ...  ...        ...
# 639995          0         0         0         0         0  ...        996
# 639996          0         0         0         0         0  ...         17
# 639997          0         0         0         0         0  ...          8
# 639998          0         0         0         0         0  ...        376
# 639999          0         0         0         0         0  ...        413
#
#         21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  23시하차총승객수  \
# 0             234        139        207        177        199        134
# 1               0          0          0          0          0          0
# 2               0          0          0          0          0          0
# 3             320        206        290        229        238        143
# 4              62         83         37         41         31         20
# ...           ...        ...        ...        ...        ...        ...
# 639995        174        847        129        914         29        373
# 639996        192         18        235         21         32          4
# 639997        376          9        337         10        100          2
# 639998        147        365        187        533          3         34
# 639999        217        382        140        452         56        154
#
#         교통수단타입코드  교통수단타입명  출근시간(04~09) 승차
# 0             10   서울간선버스            1295
# 1             51   서울심야버스              88
# 2             51   서울심야버스               0
# 3             10   서울간선버스            1887
# 4             10   서울간선버스            1449
# ...          ...      ...             ...
# 639995         0      NaN            3295
# 639996         0      NaN            5225
# 639997         0      NaN            5591
# 639998         0      NaN            5154
# 639999         0      NaN            2400
#
# [640000 rows x 55 columns]

# %%
seoul_bus_stop_commute['출근시간(07~10) 하차'] = seoul_bus_stop_commute['7시하차총승객수'] + seoul_bus_stop_commute['8시하차총승객수'] + \
                                            seoul_bus_stop_commute['9시하차총승객수'] + seoul_bus_stop_commute['10시하차총승객수']                                          
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  21시승차총승객수  \
# 0              85        95       123         0         0  ...        234
# 1               0         0         0        87        73  ...          0
# 2               5       319       232       141       155  ...          0
# 3              54         5         3         0         0  ...        320
# 4               0         0         0         0         0  ...         62
# ...           ...       ...       ...       ...       ...  ...        ...
# 639995          0         0         0         0         0  ...        174
# 639996          0         0         0         0         0  ...        192
# 639997          0         0         0         0         0  ...        376
# 639998          0         0         0         0         0  ...        147
# 639999          0         0         0         0         0  ...        217
#
#         21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  23시하차총승객수  교통수단타입코드  \
# 0             139        207        177        199        134        10
# 1               0          0          0          0          0        51
# 2               0          0          0          0          0        51
# 3             206        290        229        238        143        10
# 4              83         37         41         31         20        10
# ...           ...        ...        ...        ...        ...       ...
# 639995        847        129        914         29        373         0
# 639996         18        235         21         32          4         0
# 639997          9        337         10        100          2         0
# 639998        365        187        533          3         34         0
# 639999        382        140        452         56        154         0
#
#         교통수단타입명  출근시간(04~09) 승차  출근시간(07~10) 하차
# 0        서울간선버스            1295            1552
# 1        서울심야버스              88               0
# 2        서울심야버스               0               0
# 3        서울간선버스            1887            1476
# 4        서울간선버스            1449            2666
# ...         ...             ...             ...
# 639995      NaN            3295            1024
# 639996      NaN            5225             112
# 639997      NaN            5591             236
# 639998      NaN            5154             651
# 639999      NaN            2400            1278
#
# [640000 rows x 56 columns]

# %%
seoul_bus_stop_commute['퇴근시간(16~20) 승차'] = seoul_bus_stop_commute['16시승차총승객수'] + seoul_bus_stop_commute['17시승차총승객수'] + \
                                            seoul_bus_stop_commute['18시승차총승객수'] + seoul_bus_stop_commute['19시승차총승객수']  + \
                                            seoul_bus_stop_commute['20시승차총승객수']
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  21시하차총승객수  \
# 0              85        95       123         0         0  ...        139
# 1               0         0         0        87        73  ...          0
# 2               5       319       232       141       155  ...          0
# 3              54         5         3         0         0  ...        206
# 4               0         0         0         0         0  ...         83
# ...           ...       ...       ...       ...       ...  ...        ...
# 639995          0         0         0         0         0  ...        847
# 639996          0         0         0         0         0  ...         18
# 639997          0         0         0         0         0  ...          9
# 639998          0         0         0         0         0  ...        365
# 639999          0         0         0         0         0  ...        382
#
#         22시승차총승객수  22시하차총승객수  23시승차총승객수  23시하차총승객수  교통수단타입코드  교통수단타입명  \
# 0             207        177        199        134        10   서울간선버스
# 1               0          0          0          0        51   서울심야버스
# 2               0          0          0          0        51   서울심야버스
# 3             290        229        238        143        10   서울간선버스
# 4              37         41         31         20        10   서울간선버스
# ...           ...        ...        ...        ...       ...      ...
# 639995        129        914         29        373         0      NaN
# 639996        235         21         32          4         0      NaN
# 639997        337         10        100          2         0      NaN
# 639998        187        533          3         34         0      NaN
# 639999        140        452         56        154         0      NaN
#
#         출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차
# 0                 1295            1552            1555
# 1                   88               0               0
# 2                    0               0               0
# 3                 1887            1476            1804
# 4                 1449            2666            1500
# ...                ...             ...             ...
# 639995            3295            1024            1603
# 639996            5225             112            1498
# 639997            5591             236            2927
# 639998            5154             651            1508
# 639999            2400            1278            1897
#
# [640000 rows x 57 columns]

# %%
seoul_bus_stop_commute['퇴근시간(17~21) 하차'] = seoul_bus_stop_commute['17시하차총승객수'] + seoul_bus_stop_commute['18시하차총승객수'] + \
                                            seoul_bus_stop_commute['19시하차총승객수'] + seoul_bus_stop_commute['20시하차총승객수']   + \
                                            seoul_bus_stop_commute['21시하차총승객수']
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  22시승차총승객수  \
# 0              85        95       123         0         0  ...        207
# 1               0         0         0        87        73  ...          0
# 2               5       319       232       141       155  ...          0
# 3              54         5         3         0         0  ...        290
# 4               0         0         0         0         0  ...         37
# ...           ...       ...       ...       ...       ...  ...        ...
# 639995          0         0         0         0         0  ...        129
# 639996          0         0         0         0         0  ...        235
# 639997          0         0         0         0         0  ...        337
# 639998          0         0         0         0         0  ...        187
# 639999          0         0         0         0         0  ...        140
#
#         22시하차총승객수  23시승차총승객수  23시하차총승객수  교통수단타입코드  교통수단타입명  출근시간(04~09) 승차  \
# 0             177        199        134        10   서울간선버스            1295
# 1               0          0          0        51   서울심야버스              88
# 2               0          0          0        51   서울심야버스               0
# 3             229        238        143        10   서울간선버스            1887
# 4              41         31         20        10   서울간선버스            1449
# ...           ...        ...        ...       ...      ...             ...
# 639995        914         29        373         0      NaN            3295
# 639996         21         32          4         0      NaN            5225
# 639997         10        100          2         0      NaN            5591
# 639998        533          3         34         0      NaN            5154
# 639999        452         56        154         0      NaN            2400
#
#         출근시간(07~10) 하차  퇴근시간(16~20) 승차  퇴근시간(17~21) 하차
# 0                 1552            1555            1878
# 1                    0               0               0
# 2                    0               0               0
# 3                 1476            1804            1938
# 4                 2666            1500             346
# ...                ...             ...             ...
# 639995            1024            1603            4987
# 639996             112            1498             111
# 639997             236            2927             106
# 639998             651            1508            2258
# 639999            1278            1897            2190
#
# [640000 rows x 58 columns]

# %%
seoul_bus_stop_commute['점심시간'] = seoul_bus_stop_commute['출근시간(07~10) 하차'] - seoul_bus_stop_commute['11시승차총승객수'] -\
                                    seoul_bus_stop_commute['12시승차총승객수'] + seoul_bus_stop_commute['12시하차총승객수'] + \
                                    seoul_bus_stop_commute['1시하차총승객수']
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  22시하차총승객수  \
# 0              85        95       123         0         0  ...        177
# 1               0         0         0        87        73  ...          0
# 2               5       319       232       141       155  ...          0
# 3              54         5         3         0         0  ...        229
# 4               0         0         0         0         0  ...         41
# ...           ...       ...       ...       ...       ...  ...        ...
# 639995          0         0         0         0         0  ...        914
# 639996          0         0         0         0         0  ...         21
# 639997          0         0         0         0         0  ...         10
# 639998          0         0         0         0         0  ...        533
# 639999          0         0         0         0         0  ...        452
#
#         23시승차총승객수  23시하차총승객수  교통수단타입코드  교통수단타입명  출근시간(04~09) 승차  \
# 0             199        134        10   서울간선버스            1295
# 1               0          0        51   서울심야버스              88
# 2               0          0        51   서울심야버스               0
# 3             238        143        10   서울간선버스            1887
# 4              31         20        10   서울간선버스            1449
# ...           ...        ...       ...      ...             ...
# 639995         29        373         0      NaN            3295
# 639996         32          4         0      NaN            5225
# 639997        100          2         0      NaN            5591
# 639998          3         34         0      NaN            5154
# 639999         56        154         0      NaN            2400
#
#         출근시간(07~10) 하차  퇴근시간(16~20) 승차  퇴근시간(17~21) 하차  점심시간
# 0                 1552            1555            1878  1402
# 1                    0               0               0     0
# 2                    0               0               0   232
# 3                 1476            1804            1938   883
# 4                 2666            1500             346  2554
# ...                ...             ...             ...   ...
# 639995            1024            1603            4987   680
# 639996             112            1498             111  -852
# 639997             236            2927             106 -1112
# 639998             651            1508            2258   -87
# 639999            1278            1897            2190   859
#
# [640000 rows x 59 columns]

# %%
seoul_bus_stop_commute['저녁시간'] = seoul_bus_stop_commute['출근시간(07~10) 하차'] - seoul_bus_stop_commute['17시승차총승객수'] -\
                                    seoul_bus_stop_commute['18시승차총승객수'] - seoul_bus_stop_commute['19시승차총승객수'] - \
                                    seoul_bus_stop_commute['20시승차총승객수'] - seoul_bus_stop_commute['17시하차총승객수'] -\
                                    seoul_bus_stop_commute['18시하차총승객수'] - seoul_bus_stop_commute['19시하차총승객수'] - \
                                    seoul_bus_stop_commute['20시하차총승객수']
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  23시승차총승객수  \
# 0              85        95       123         0         0  ...        199
# 1               0         0         0        87        73  ...          0
# 2               5       319       232       141       155  ...          0
# 3              54         5         3         0         0  ...        238
# 4               0         0         0         0         0  ...         31
# ...           ...       ...       ...       ...       ...  ...        ...
# 639995          0         0         0         0         0  ...         29
# 639996          0         0         0         0         0  ...         32
# 639997          0         0         0         0         0  ...        100
# 639998          0         0         0         0         0  ...          3
# 639999          0         0         0         0         0  ...         56
#
#         23시하차총승객수  교통수단타입코드  교통수단타입명  출근시간(04~09) 승차  출근시간(07~10) 하차  \
# 0             134        10   서울간선버스            1295            1552
# 1               0        51   서울심야버스              88               0
# 2               0        51   서울심야버스               0               0
# 3             143        10   서울간선버스            1887            1476
# 4              20        10   서울간선버스            1449            2666
# ...           ...       ...      ...             ...             ...
# 639995        373         0      NaN            3295            1024
# 639996          4         0      NaN            5225             112
# 639997          2         0      NaN            5591             236
# 639998         34         0      NaN            5154             651
# 639999        154         0      NaN            2400            1278
#
#         퇴근시간(16~20) 승차  퇴근시간(17~21) 하차  점심시간  저녁시간
# 0                 1555            1878  1402 -1447
# 1                    0               0     0     0
# 2                    0               0   232     0
# 3                 1804            1938   883 -1754
# 4                 1500             346  2554  1229
# ...                ...             ...   ...   ...
# 639995            1603            4987   680 -4315
# 639996            1498             111  -852 -1078
# 639997            2927             106 -1112 -2024
# 639998            1508            2258   -87 -2362
# 639999            1897            2190   859 -1888
#
# [640000 rows x 60 columns]

# %%
seoul_bus_stop_commute['늦은시간(20~00) 승차'] = seoul_bus_stop_commute['20시승차총승객수'] + seoul_bus_stop_commute['21시승차총승객수'] + \
                                            seoul_bus_stop_commute['22시승차총승객수'] + seoul_bus_stop_commute['23시승차총승객수']  + \
                                            seoul_bus_stop_commute['00시승차총승객수']
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  23시하차총승객수  \
# 0              85        95       123         0         0  ...        134
# 1               0         0         0        87        73  ...          0
# 2               5       319       232       141       155  ...          0
# 3              54         5         3         0         0  ...        143
# 4               0         0         0         0         0  ...         20
# ...           ...       ...       ...       ...       ...  ...        ...
# 639995          0         0         0         0         0  ...        373
# 639996          0         0         0         0         0  ...          4
# 639997          0         0         0         0         0  ...          2
# 639998          0         0         0         0         0  ...         34
# 639999          0         0         0         0         0  ...        154
#
#         교통수단타입코드  교통수단타입명  출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  \
# 0             10   서울간선버스            1295            1552            1555
# 1             51   서울심야버스              88               0               0
# 2             51   서울심야버스               0               0               0
# 3             10   서울간선버스            1887            1476            1804
# 4             10   서울간선버스            1449            2666            1500
# ...          ...      ...             ...             ...             ...
# 639995         0      NaN            3295            1024            1603
# 639996         0      NaN            5225             112            1498
# 639997         0      NaN            5591             236            2927
# 639998         0      NaN            5154             651            1508
# 639999         0      NaN            2400            1278            1897
#
#         퇴근시간(17~21) 하차  점심시간  저녁시간  늦은시간(20~00) 승차
# 0                 1878  1402 -1447            1070
# 1                    0     0     0               0
# 2                    0   232     0               6
# 3                 1938   883 -1754            1287
# 4                  346  2554  1229             419
# ...                ...   ...   ...             ...
# 639995            4987   680 -4315             506
# 639996             111  -852 -1078             703
# 639997             106 -1112 -2024            1182
# 639998            2258   -87 -2362             613
# 639999            2190   859 -1888             636
#
# [640000 rows x 61 columns]

# %%
seoul_bus_stop_commute['늦은시간(21~02) 하차'] = seoul_bus_stop_commute['21시하차총승객수'] + seoul_bus_stop_commute['22시하차총승객수'] + \
                                            seoul_bus_stop_commute['23시하차총승객수'] + seoul_bus_stop_commute['00시하차총승객수']  + \
                                            seoul_bus_stop_commute['1시하차총승객수'] + seoul_bus_stop_commute['2시하차총승객수']
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  교통수단타입코드  \
# 0              85        95       123         0         0  ...        10
# 1               0         0         0        87        73  ...        51
# 2               5       319       232       141       155  ...        51
# 3              54         5         3         0         0  ...        10
# 4               0         0         0         0         0  ...        10
# ...           ...       ...       ...       ...       ...  ...       ...
# 639995          0         0         0         0         0  ...         0
# 639996          0         0         0         0         0  ...         0
# 639997          0         0         0         0         0  ...         0
# 639998          0         0         0         0         0  ...         0
# 639999          0         0         0         0         0  ...         0
#
#         교통수단타입명  출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  \
# 0        서울간선버스            1295            1552            1555
# 1        서울심야버스              88               0               0
# 2        서울심야버스               0               0               0
# 3        서울간선버스            1887            1476            1804
# 4        서울간선버스            1449            2666            1500
# ...         ...             ...             ...             ...
# 639995      NaN            3295            1024            1603
# 639996      NaN            5225             112            1498
# 639997      NaN            5591             236            2927
# 639998      NaN            5154             651            1508
# 639999      NaN            2400            1278            1897
#
#         퇴근시간(17~21) 하차  점심시간  저녁시간  늦은시간(20~00) 승차  늦은시간(21~02) 하차
# 0                 1878  1402 -1447            1070             658
# 1                    0     0     0               0              73
# 2                    0   232     0               6             392
# 3                 1938   883 -1754            1287             635
# 4                  346  2554  1229             419             144
# ...                ...   ...   ...             ...             ...
# 639995            4987   680 -4315             506            2134
# 639996             111  -852 -1078             703              43
# 639997             106 -1112 -2024            1182              21
# 639998            2258   -87 -2362             613             932
# 639999            2190   859 -1888             636             988
#
# [640000 rows x 62 columns]

# %%
seoul_bus_stop_commute['총 승차 인원'] = seoul_bus_stop_commute['00시승차총승객수']
for i in range(1,24):
    STR = str(i) + "시승차총승객수"
    seoul_bus_stop_commute['총 승차 인원'] = seoul_bus_stop_commute['총 승차 인원'] + seoul_bus_stop_commute[STR]

seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  교통수단타입명  \
# 0              85        95       123         0         0  ...   서울간선버스
# 1               0         0         0        87        73  ...   서울심야버스
# 2               5       319       232       141       155  ...   서울심야버스
# 3              54         5         3         0         0  ...   서울간선버스
# 4               0         0         0         0         0  ...   서울간선버스
# ...           ...       ...       ...       ...       ...  ...      ...
# 639995          0         0         0         0         0  ...      NaN
# 639996          0         0         0         0         0  ...      NaN
# 639997          0         0         0         0         0  ...      NaN
# 639998          0         0         0         0         0  ...      NaN
# 639999          0         0         0         0         0  ...      NaN
#
#         출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  퇴근시간(17~21) 하차  점심시간  \
# 0                 1295            1552            1555            1878  1402
# 1                   88               0               0               0     0
# 2                    0               0               0               0   232
# 3                 1887            1476            1804            1938   883
# 4                 1449            2666            1500             346  2554
# ...                ...             ...             ...             ...   ...
# 639995            3295            1024            1603            4987   680
# 639996            5225             112            1498             111  -852
# 639997            5591             236            2927             106 -1112
# 639998            5154             651            1508            2258   -87
# 639999            2400            1278            1897            2190   859
#
#         저녁시간  늦은시간(20~00) 승차  늦은시간(21~02) 하차  총 승차 인원
# 0      -1447            1070             658     5622
# 1          0               0              73      393
# 2          0               6             392      466
# 3      -1754            1287             635     7645
# 4       1229             419             144     4373
# ...      ...             ...             ...      ...
# 639995 -4315             506            2134     7412
# 639996 -1078             703              43    10162
# 639997 -2024            1182              21    13690
# 639998 -2362             613             932     9630
# 639999 -1888             636             988     6721
#
# [640000 rows x 63 columns]

# %%
seoul_bus_stop_commute['총 하차 인원'] = seoul_bus_stop_commute['00시하차총승객수']
for i in range(1,24):
    STR = str(i) + "시하차총승객수"
    seoul_bus_stop_commute['총 하차 인원'] = seoul_bus_stop_commute['총 하차 인원'] + seoul_bus_stop_commute[STR]

seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  00시승차총승객수  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        122
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)          0
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)          6
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)         59
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)          0
# ...        ...   ...                    ...                 ...        ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞          0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞          0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞          0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞          0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞          0
#
#         00시하차총승객수  1시승차총승객수  1시하차총승객수  2시승차총승객수  2시하차총승객수  ...  \
# 0              85        95       123         0         0  ...
# 1               0         0         0        87        73  ...
# 2               5       319       232       141       155  ...
# 3              54         5         3         0         0  ...
# 4               0         0         0         0         0  ...
# ...           ...       ...       ...       ...       ...  ...
# 639995          0         0         0         0         0  ...
# 639996          0         0         0         0         0  ...
# 639997          0         0         0         0         0  ...
# 639998          0         0         0         0         0  ...
# 639999          0         0         0         0         0  ...
#
#         출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  퇴근시간(17~21) 하차  점심시간  \
# 0                 1295            1552            1555            1878  1402
# 1                   88               0               0               0     0
# 2                    0               0               0               0   232
# 3                 1887            1476            1804            1938   883
# 4                 1449            2666            1500             346  2554
# ...                ...             ...             ...             ...   ...
# 639995            3295            1024            1603            4987   680
# 639996            5225             112            1498             111  -852
# 639997            5591             236            2927             106 -1112
# 639998            5154             651            1508            2258   -87
# 639999            2400            1278            1897            2190   859
#
#         저녁시간  늦은시간(20~00) 승차  늦은시간(21~02) 하차  총 승차 인원  총 하차 인원
# 0      -1447            1070             658     5622     6619
# 1          0               0              73      393      354
# 2          0               6             392      466      392
# 3      -1754            1287             635     7645     6872
# 4       1229             419             144     4373     5461
# ...      ...             ...             ...      ...      ...
# 639995 -4315             506            2134     7412    10079
# 639996 -1078             703              43    10162      399
# 639997 -2024            1182              21    13690      547
# 639998 -2362             613             932     9630     5216
# 639999 -1888             636             988     6721     5818
#
# [640000 rows x 64 columns]

# %%
seoul_bus_stop_commute = seoul_bus_stop_commute.drop(['00시승차총승객수', '00시하차총승객수'], axis = 1 )
for i in range(1,24):
    STR = str(i) + "시승차총승객수"
    STR_2 = str(i) + "시하차총승객수"
    seoul_bus_stop_commute = seoul_bus_stop_commute.drop([STR, STR_2], axis = 1 )

seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명  교통수단타입코드  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)        10
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)        51
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)        51
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)        10
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)        10
# ...        ...   ...                    ...                 ...       ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞         0
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞         0
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞         0
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞         0
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞         0
#
#        교통수단타입명  출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  \
# 0       서울간선버스            1295            1552            1555
# 1       서울심야버스              88               0               0
# 2       서울심야버스               0               0               0
# 3       서울간선버스            1887            1476            1804
# 4       서울간선버스            1449            2666            1500
# ...        ...             ...             ...             ...
# 639995     NaN            3295            1024            1603
# 639996     NaN            5225             112            1498
# 639997     NaN            5591             236            2927
# 639998     NaN            5154             651            1508
# 639999     NaN            2400            1278            1897
#
#         퇴근시간(17~21) 하차  점심시간  저녁시간  늦은시간(20~00) 승차  늦은시간(21~02) 하차  총 승차 인원  \
# 0                 1878  1402 -1447            1070             658     5622
# 1                    0     0     0               0              73      393
# 2                    0   232     0               6             392      466
# 3                 1938   883 -1754            1287             635     7645
# 4                  346  2554  1229             419             144     4373
# ...                ...   ...   ...             ...             ...      ...
# 639995            4987   680 -4315             506            2134     7412
# 639996             111  -852 -1078             703              43    10162
# 639997             106 -1112 -2024            1182              21    13690
# 639998            2258   -87 -2362             613             932     9630
# 639999            2190   859 -1888             636             988     6721
#
#         총 하차 인원
# 0          6619
# 1           354
# 2           392
# 3          6872
# 4          5461
# ...         ...
# 639995    10079
# 639996      399
# 639997      547
# 639998     5216
# 639999     5818
#
# [640000 rows x 16 columns]

# %%
seoul_bus_stop_commute = seoul_bus_stop_commute.drop(['교통수단타입코드'], axis = 1 )
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명 교통수단타입명  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)  서울간선버스
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)  서울심야버스
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)  서울심야버스
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)  서울간선버스
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)  서울간선버스
# ...        ...   ...                    ...                 ...     ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞     NaN
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞     NaN
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞     NaN
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞     NaN
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞     NaN
#
#         출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  퇴근시간(17~21) 하차  점심시간  \
# 0                 1295            1552            1555            1878  1402
# 1                   88               0               0               0     0
# 2                    0               0               0               0   232
# 3                 1887            1476            1804            1938   883
# 4                 1449            2666            1500             346  2554
# ...                ...             ...             ...             ...   ...
# 639995            3295            1024            1603            4987   680
# 639996            5225             112            1498             111  -852
# 639997            5591             236            2927             106 -1112
# 639998            5154             651            1508            2258   -87
# 639999            2400            1278            1897            2190   859
#
#         저녁시간  늦은시간(20~00) 승차  늦은시간(21~02) 하차  총 승차 인원  총 하차 인원
# 0      -1447            1070             658     5622     6619
# 1          0               0              73      393      354
# 2          0               6             392      466      392
# 3      -1754            1287             635     7645     6872
# 4       1229             419             144     4373     5461
# ...      ...             ...             ...      ...      ...
# 639995 -4315             506            2134     7412    10079
# 639996 -1078             703              43    10162      399
# 639997 -2024            1182              21    13690      547
# 639998 -2362             613             932     9630     5216
# 639999 -1888             636             988     6721     5818
#
# [640000 rows x 15 columns]

# %%
#seoul_bus_stop_commute["연도"] =  seoul_bus_stop_commute["사용년월"].str[:4]
seoul_bus_stop_commute.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640000 entries, 0 to 639999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   사용년월            640000 non-null  int64
#  1   노선번호            640000 non-null  object
#  2   노선명             640000 non-null  object
#  3   역명              640000 non-null  object
#  4   교통수단타입명         162055 non-null  object
#  5   출근시간(04~09) 승차  640000 non-null  int64
#  6   출근시간(07~10) 하차  640000 non-null  int64
#  7   퇴근시간(16~20) 승차  640000 non-null  int64
#  8   퇴근시간(17~21) 하차  640000 non-null  int64
#  9   점심시간            640000 non-null  int64
#  10  저녁시간            640000 non-null  int64
#  11  늦은시간(20~00) 승차  640000 non-null  int64
#  12  늦은시간(21~02) 하차  640000 non-null  int64
#  13  총 승차 인원         640000 non-null  int64
#  14  총 하차 인원         640000 non-null  int64
# dtypes: int64(11), object(4)
# memory usage: 73.2+ MB

# %%
seoul_bus_stop_commute = seoul_bus_stop_commute.astype({'사용년월' : 'string'})

# %%
seoul_bus_stop_commute["연도"] =  seoul_bus_stop_commute["사용년월"].str[:4]
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명                  역명 교통수단타입명  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리(00077)  서울간선버스
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리(00089)  서울심야버스
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리(00032)  서울심야버스
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리(00067)  서울간선버스
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원(00024)  서울간선버스
# ...        ...   ...                    ...                 ...     ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)           국민은행자양지점앞     NaN
# 639996  202106  2415         2415번(자양동~대치동)           국민은행자양지점앞     NaN
# 639997  202106  2221         2221번(자양동~신설동)           국민은행자양지점앞     NaN
# 639998  202106  2412      2412번(성수동~세곡동사거리)           국민은행자양지점앞     NaN
# 639999  202106  광진05       광진05(신자초등학교~강변역)              자양아파트앞     NaN
#
#         출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  퇴근시간(17~21) 하차  점심시간  \
# 0                 1295            1552            1555            1878  1402
# 1                   88               0               0               0     0
# 2                    0               0               0               0   232
# 3                 1887            1476            1804            1938   883
# 4                 1449            2666            1500             346  2554
# ...                ...             ...             ...             ...   ...
# 639995            3295            1024            1603            4987   680
# 639996            5225             112            1498             111  -852
# 639997            5591             236            2927             106 -1112
# 639998            5154             651            1508            2258   -87
# 639999            2400            1278            1897            2190   859
#
#         저녁시간  늦은시간(20~00) 승차  늦은시간(21~02) 하차  총 승차 인원  총 하차 인원    연도
# 0      -1447            1070             658     5622     6619  2022
# 1          0               0              73      393      354  2022
# 2          0               6             392      466      392  2022
# 3      -1754            1287             635     7645     6872  2022
# 4       1229             419             144     4373     5461  2022
# ...      ...             ...             ...      ...      ...   ...
# 639995 -4315             506            2134     7412    10079  2021
# 639996 -1078             703              43    10162      399  2021
# 639997 -2024            1182              21    13690      547  2021
# 639998 -2362             613             932     9630     5216  2021
# 639999 -1888             636             988     6721     5818  2021
#
# [640000 rows x 16 columns]

# %%
for i in range(len(seoul_bus_stop_commute)):
    if seoul_bus_stop_commute['역명'][i][len(seoul_bus_stop_commute['역명'][i])-1:] == ')':
        seoul_bus_stop_commute_tmp['역명'][i] = seoul_bus_stop_commute_tmp['역명'][i][:(len(seoul_bus_stop_commute_tmp['역명'][i])-7)]
# Out:
# /tmp/ipykernel_8677/4138503587.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_bus_stop_commute_tmp['역명'][i] = seoul_bus_stop_commute_tmp['역명'][i][:(len(seoul_bus_stop_commute_tmp['역명'][i])-7)]

# %%
seoul_bus_stop_commute
# Out:
#           사용년월  노선번호                    노선명           역명 교통수단타입명  \
# 0       202210   741      741번(진관차고지~헌인릉입구)      종로2가사거리  서울간선버스
# 1       202210   N37  N37번(진관공영차고지~송파공영차고지)      종로2가사거리  서울심야버스
# 2       202210   N37  N37번(송파공영차고지~진관공영차고지)      종로2가사거리  서울심야버스
# 3       202210   470       470번(상암차고지~안골마을)      종로2가사거리  서울간선버스
# 4       202210   104   104번(강북청소년수련관난나~숭례문)  창경궁.서울대학교병원  서울간선버스
# ...        ...   ...                    ...          ...     ...
# 639995  202106  광진05       광진05(신자초등학교~강변역)    국민은행자양지점앞     NaN
# 639996  202106  2415         2415번(자양동~대치동)    국민은행자양지점앞     NaN
# 639997  202106  2221         2221번(자양동~신설동)    국민은행자양지점앞     NaN
# 639998  202106  2412      2412번(성수동~세곡동사거리)    국민은행자양지점앞     NaN
# 639999  202106  광진05       광진05(신자초등학교~강변역)       자양아파트앞     NaN
#
#         출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  퇴근시간(17~21) 하차  점심시간  \
# 0                 1295            1552            1555            1878  1402
# 1                   88               0               0               0     0
# 2                    0               0               0               0   232
# 3                 1887            1476            1804            1938   883
# 4                 1449            2666            1500             346  2554
# ...                ...             ...             ...             ...   ...
# 639995            3295            1024            1603            4987   680
# 639996            5225             112            1498             111  -852
# 639997            5591             236            2927             106 -1112
# 639998            5154             651            1508            2258   -87
# 639999            2400            1278            1897            2190   859
#
#         저녁시간  늦은시간(20~00) 승차  늦은시간(21~02) 하차  총 승차 인원  총 하차 인원    연도
# 0      -1447            1070             658     5622     6619  2022
# 1          0               0              73      393      354  2022
# 2          0               6             392      466      392  2022
# 3      -1754            1287             635     7645     6872  2022
# 4       1229             419             144     4373     5461  2022
# ...      ...             ...             ...      ...      ...   ...
# 639995 -4315             506            2134     7412    10079  2021
# 639996 -1078             703              43    10162      399  2021
# 639997 -2024            1182              21    13690      547  2021
# 639998 -2362             613             932     9630     5216  2021
# 639999 -1888             636             988     6721     5818  2021
#
# [640000 rows x 16 columns]

# %%
seoul_bus_stop_commute = seoul_bus_stop_commute.drop(['노선번호', '노선명', '교통수단타입명'], axis = 1 )
seoul_bus_stop_commute
# Out:
#           사용년월           역명  출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  \
# 0       202210      종로2가사거리            1295            1552            1555
# 1       202210      종로2가사거리              88               0               0
# 2       202210      종로2가사거리               0               0               0
# 3       202210      종로2가사거리            1887            1476            1804
# 4       202210  창경궁.서울대학교병원            1449            2666            1500
# ...        ...          ...             ...             ...             ...
# 639995  202106    국민은행자양지점앞            3295            1024            1603
# 639996  202106    국민은행자양지점앞            5225             112            1498
# 639997  202106    국민은행자양지점앞            5591             236            2927
# 639998  202106    국민은행자양지점앞            5154             651            1508
# 639999  202106       자양아파트앞            2400            1278            1897
#
#         퇴근시간(17~21) 하차  점심시간  저녁시간  늦은시간(20~00) 승차  늦은시간(21~02) 하차  총 승차 인원  \
# 0                 1878  1402 -1447            1070             658     5622
# 1                    0     0     0               0              73      393
# 2                    0   232     0               6             392      466
# 3                 1938   883 -1754            1287             635     7645
# 4                  346  2554  1229             419             144     4373
# ...                ...   ...   ...             ...             ...      ...
# 639995            4987   680 -4315             506            2134     7412
# 639996             111  -852 -1078             703              43    10162
# 639997             106 -1112 -2024            1182              21    13690
# 639998            2258   -87 -2362             613             932     9630
# 639999            2190   859 -1888             636             988     6721
#
#         총 하차 인원    연도
# 0          6619  2022
# 1           354  2022
# 2           392  2022
# 3          6872  2022
# 4          5461  2022
# ...         ...   ...
# 639995    10079  2021
# 639996      399  2021
# 639997      547  2021
# 639998     5216  2021
# 639999     5818  2021
#
# [640000 rows x 13 columns]
