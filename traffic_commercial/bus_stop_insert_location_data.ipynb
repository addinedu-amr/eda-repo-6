# %% [markdown]
# # (4/4)
# # 서울시 버스정류장별 위치데이터를 얻어왔습니다.
# http://data.seoul.go.kr/dataList/OA-15067/S/1/datasetView.do#
#
# ## 이 데이터를 (3/4)의 데이터에 저장하는 것이 이번 가공의 목적입니다.

# %%
import pandas as pd

# %%
#2022 , 2021년의 경우
#bus_location_2022_10 = pd.read_csv('./2022_bus_location.csv', encoding='EUC-KR')
#bus_location_2022_10 = bus_location_2022_10.drop(['정류소명', 'ARS-ID'], axis=1)

bus_location_2022_10 = pd.read_excel('./2019_bus_location.xlsx')
#2019년의 경우 바뀜
bus_location_2022_10 = bus_location_2022_10.drop(['정류장명', 'ARSID'], axis=1)
#bus_location_2022_10 = bus_location_2022_10.drop(['정류장명', 'ARS-ID', '비고'], axis=1)
bus_location_2022_10
# Out:
#             표준ID         X좌표        Y좌표
# 0      100000001  126.987786  37.569764
# 1      100000002  126.996520  37.579179
# 2      100000003  126.998290  37.582709
# 3      100000004  126.987507  37.568582
# 4      100000005  127.001694  37.586230
# ...          ...         ...        ...
# 11175  124000334  127.139326  37.550442
# 11176  124000333  127.140052  37.550620
# 11177  124000332  127.123477  37.533686
# 11178  124000331  127.125410  37.536199
# 11179  124000330  127.127354  37.540390
#
# [11180 rows x 3 columns]

# %%
bus_data_2022_10 = pd.read_csv('./bus_stop_file/bus_data_2019_10_final.csv')
bus_data_2022_10
# Out:
#          연도   월  표준버스정류장ID             역명  환승 가능한 버스의 수  총 승차 인원  총 하차 인원  \
# 0      2022  10  100000001        종로2가사거리             4    15331    18343
# 1      2022  10  100000002    창경궁.서울대학교병원            17    82567    72002
# 2      2022  10  100000003      명륜3가.성대입구            17   140393   101718
# 3      2022  10  100000004       종로2가.삼일교             5    24172    25003
# 4      2022  10  100000005  혜화동로터리.여운형활동터            16    54650    95239
# ...     ...  ..        ...            ...           ...      ...      ...
# 12641  2022  10  999800001            김포교             6      902       75
# 12642  2022  10  999800002            김포교             6        0       88
# 12643  2022  10  999800003          구미동차고             1       85       83
# 12644  2022  10  999800004          구미동차고             1        0       98
# 12645  2022  10  999800005           가좌동종             2        0      298
#
#        출근시간(04~09) 승차  출근시간(07~10) 하차  퇴근시간(16~20) 승차  퇴근시간(17~21) 하차  \
# ...

# %%
#2022년의 경우 NODE_ID
bus_data_2022_10_insert =pd.merge(bus_data_2022_10, bus_location_2022_10, left_on='표준버스정류장ID', right_on='표준ID', how='inner')
bus_data_2022_10_insert
# Out:
#          연도   월  표준버스정류장ID               역명  환승 가능한 버스의 수  총 승차 인원  총 하차 인원  \
# 0      2022  10  100000001          종로2가사거리             4    15331    18343
# 1      2022  10  100000002      창경궁.서울대학교병원            17    82567    72002
# 2      2022  10  100000003        명륜3가.성대입구            17   140393   101718
# 3      2022  10  100000004         종로2가.삼일교             5    24172    25003
# 4      2022  10  100000005    혜화동로터리.여운형활동터            16    54650    95239
# ...     ...  ..        ...              ...           ...      ...      ...
# 10515  2022  10  124900109           고덕초등학교             2      482      969
# 10516  2022  10  124900110            고덕2단지             2     2049     2228
# 10517  2022  10  124900111             가래여울             1       39     2253
# 10518  2022  10  124900112  고덕래미안힐스테이트시니어센터             2     2092    12114
# 10519  2022  10  129000186            효죽동입구             1     3440     1590
#
# ...

# %%
bus_data_2022_10_insert = bus_data_2022_10_insert.drop(['표준ID'], axis=1)
bus_data_2022_10_insert
# Out:
#          연도   월  표준버스정류장ID               역명  환승 가능한 버스의 수  총 승차 인원  총 하차 인원  \
# 0      2022  10  100000001          종로2가사거리             4    15331    18343
# 1      2022  10  100000002      창경궁.서울대학교병원            17    82567    72002
# 2      2022  10  100000003        명륜3가.성대입구            17   140393   101718
# 3      2022  10  100000004         종로2가.삼일교             5    24172    25003
# 4      2022  10  100000005    혜화동로터리.여운형활동터            16    54650    95239
# ...     ...  ..        ...              ...           ...      ...      ...
# 10515  2022  10  124900109           고덕초등학교             2      482      969
# 10516  2022  10  124900110            고덕2단지             2     2049     2228
# 10517  2022  10  124900111             가래여울             1       39     2253
# 10518  2022  10  124900112  고덕래미안힐스테이트시니어센터             2     2092    12114
# 10519  2022  10  129000186            효죽동입구             1     3440     1590
#
# ...

# %% [markdown]
# # 최종 버스 데이터입니다.

# %%
bus_data_2022_10_insert.to_csv('./2019_10_bus_data_final.csv', index=False)
