# %%
import pandas as pd

# %%
fail = pd.read_csv('./카카오에서도실패.csv', encoding='EUC-KR')
fail
# Out:
#     Unnamed: 0  실패인덱스  index                위치                도로명 포함 주소  url  \
# 0            5    5.0      5               안양교               서부간선도로 안양교  NaN
# 1            7    7.0      7             이화교동단               중랑천로 이화교동단  NaN
# 2            8    8.0      8             오금교동측             서부간선도로 오금교동측  NaN
# 3           10   10.0     10      올림픽대로동부간선분기점    테헤란로115길 올림픽대로동부간선분기점  NaN
# 4           13   13.0     13             워베스빌앞             목동중앙본로 워베스빌앞  NaN
# ..         ...    ...    ...               ...                      ...  ...
# 56         207  207.0    207            뚝섬정수장앞              강변북로 뚝섬정수장앞  NaN
# 57         208  208.0    208              선암UD               강남순환로 선암UD  NaN
# 58         209  209.0    209       올림픽대로동부간선JC        올림픽대로 올림픽대로동부간선JC  NaN
# 59         211  211.0    211            수출입은행뒤               은행로 수출입은행뒤  NaN
# 60         222  222.0    222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프  NaN
#
#     long  lat  실패_인덱스
# 0    NaN  NaN      46
# 1    NaN  NaN      58
# 2    NaN  NaN      71
# 3    NaN  NaN      89
# 4    NaN  NaN     132
# ..   ...  ...     ...
# 56   NaN  NaN    2931
# 57   NaN  NaN    2940
# 58   NaN  NaN    2955
# 59   NaN  NaN    3023
# 60   NaN  NaN    1875
#
# [61 rows x 9 columns]

# %% [markdown]
# # 도저히 찾을 수가 없어 직접 위치를 찍겠습니다.

# %%
fail = pd.read_csv('./카카오에서도실패.csv', encoding='EUC-KR')
fail
# Out:
#     Unnamed: 0  실패인덱스  index                위치                도로명 포함 주소  \
# 0            5      5      5               안양교               서부간선도로 안양교
# 1            7      7      7             이화교동단               중랑천로 이화교동단
# 2            8      8      8             오금교동측             서부간선도로 오금교동측
# 3           10     10     10      올림픽대로동부간선분기점    테헤란로115길 올림픽대로동부간선분기점
# 4           13     13     13             워베스빌앞             목동중앙본로 워베스빌앞
# ..         ...    ...    ...               ...                      ...
# 56         207    207    207            뚝섬정수장앞              강변북로 뚝섬정수장앞
# 57         208    208    208              선암UD               강남순환로 선암UD
# 58         209    209    209       올림픽대로동부간선JC        올림픽대로 올림픽대로동부간선JC
# 59         211    211    211            수출입은행뒤               은행로 수출입은행뒤
# 60         222    222    222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
#
#                          url  long  lat  실패_인덱스
# 0   http://kko.to/RZf5ImT8PW   NaN  NaN      46
# 1   http://kko.to/r3sNgdQ0XI   NaN  NaN      58
# 2   http://kko.to/Li1jUcY08j   NaN  NaN      71
# 3   http://kko.to/Lky947e5nD   NaN  NaN      89
# 4   http://kko.to/Gu8cRur72l   NaN  NaN     132
# ..                       ...   ...  ...     ...
# 56  http://kko.to/CMk-Eo8YfN   NaN  NaN    2931
# 57  http://kko.to/Cvwa08Zao1   NaN  NaN    2940
# 58  http://kko.to/sWimX1Z4Zd   NaN  NaN    2955
# 59  http://kko.to/crFUEKV-N0   NaN  NaN    3023
# 60  http://kko.to/Q4AwqSdVsl   NaN  NaN    1875
#
# [61 rows x 9 columns]

# %%
result = pd.read_csv('./카카오결과_1차.csv', encoding='EUC-KR')

# %%
result.head(20)
# Out:
#     Unnamed: 0  index             위치              도로명 포함 주소  \
# 0            0      0      우이제3교(북단)         우이천로 우이제3교(북단)
# 1            1      1  홍은램프진입(내부순환로)    내부순환로 홍은램프진입(내부순환로)
# 2            2      2         암사정수센터            아리수로 암사정수센터
# 3            3      3        한국방송공사앞           여의서로 한국방송공사앞
# 4            4      4         여의하류IC             노들로 여의하류IC
# 5            5      5            안양교             서부간선도로 안양교
# 6            6      6         유수지주차장            면목천로 유수지주차장
# 7            7      7          이화교동단             중랑천로 이화교동단
# 8            8      8          오금교동측           서부간선도로 오금교동측
# 9            9      9      월드컵파크12단지        월드컵북로 월드컵파크12단지
# 10          10     10   올림픽대로동부간선분기점  테헤란로115길 올림픽대로동부간선분기점
# 11          11     11            창동교             동부간선도로 창동교
# 12          12     12           E-마트               동남로 E-마트
# 13          13     13          워베스빌앞           목동중앙본로 워베스빌앞
# 14          14     14        종합운동장JC           한가람로 종합운동장JC
# 15          15     15           대명초교               상암로 대명초교
# 16          16     16           가양IC             올림픽대로 가양IC
# 17          17     17          용마T/G             용마터널 용마T/G
# 18          18     18          상원삼거리             성수일로 상원삼거리
# 19          19     19          민마루고개             양재대로 민마루고개
#
#                          url  long  lat  실패_인덱스
# 0   http://kko.to/u8zRmeRQJd   NaN  NaN       7
# 1   http://kko.to/StbHDfgnFN   NaN  NaN      21
# 2   http://kko.to/dn_Gnm85oJ   NaN  NaN      37
# 3   http://kko.to/yzK_6dH2ww   NaN  NaN      39
# 4   http://kko.to/9GQduBLMEA   NaN  NaN      44
# 5                        NaN   NaN  NaN      46
# 6   http://kko.to/27sZDpyT8q   NaN  NaN      49
# 7                        NaN   NaN  NaN      58
# 8                        NaN   NaN  NaN      71
# 9   http://kko.to/8lfSPc0kmJ   NaN  NaN      88
# 10                       NaN   NaN  NaN      89
# 11  http://kko.to/EuVlzaHjcI   NaN  NaN     101
# 12  http://kko.to/q-YigLwHd1   NaN  NaN     113
# 13                       NaN   NaN  NaN     132
# 14  http://kko.to/L1N8RW8Soq   NaN  NaN     142
# 15  http://kko.to/CbhCf2vwL4   NaN  NaN     196
# 16  http://kko.to/oal8kWiVSu   NaN  NaN     214
# 17                       NaN   NaN  NaN     216
# 18  http://kko.to/_wqE0_kOf9   NaN  NaN     258
# 19                       NaN   NaN  NaN     291

# %%
fail['실패인덱스']
# Out:
# 0       5
# 1       7
# 2       8
# 3      10
# 4      13
#      ...
# 56    207
# 57    208
# 58    209
# 59    211
# 60    222
# Name: 실패인덱스, Length: 61, dtype: int64

# %%
count = 0
for i in fail['실패인덱스']:
    result["url"][i] = fail['url'][count]
    count = count + 1
result
# Out:
# C:\Users\김두엽\AppData\Local\Temp\ipykernel_11460\2738763270.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result["url"][i] = fail['url'][count]
#      Unnamed: 0  index                위치                도로명 포함 주소  \
# 0             0      0         우이제3교(북단)           우이천로 우이제3교(북단)
# 1             1      1     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2             2      2            암사정수센터              아리수로 암사정수센터
# 3             3      3           한국방송공사앞             여의서로 한국방송공사앞
# 4             4      4            여의하류IC               노들로 여의하류IC
# ..          ...    ...               ...                      ...
# 220         220    220            잠실3삼거리               삼전로 잠실3삼거리
# 221         221    221            대방천사거리              대방천로 대방천사거리
# 222         222    222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223         223    223            북한남삼거리              이태원로 북한남삼거리
# 224         224    224            북한남삼거리              한남대로 북한남삼거리
#
#                           url  long  lat  실패_인덱스
# 0    http://kko.to/u8zRmeRQJd   NaN  NaN       7
# 1    http://kko.to/StbHDfgnFN   NaN  NaN      21
# 2    http://kko.to/dn_Gnm85oJ   NaN  NaN      37
# 3    http://kko.to/yzK_6dH2ww   NaN  NaN      39
# 4    http://kko.to/9GQduBLMEA   NaN  NaN      44
# ..                        ...   ...  ...     ...
# 220  http://kko.to/yNPtksQ8qu   NaN  NaN    3130
# 221  http://kko.to/iG5tEPnxmM   NaN  NaN    3132
# 222  http://kko.to/Q4AwqSdVsl   NaN  NaN    1875
# 223  http://kko.to/ELeVBpiUyE   NaN  NaN     663
# 224  http://kko.to/ELeVBpiUyE   NaN  NaN    1475
#
# [225 rows x 8 columns]

# %%
result.head(20)
# Out:
#     Unnamed: 0  index             위치              도로명 포함 주소  \
# 0            0      0      우이제3교(북단)         우이천로 우이제3교(북단)
# 1            1      1  홍은램프진입(내부순환로)    내부순환로 홍은램프진입(내부순환로)
# 2            2      2         암사정수센터            아리수로 암사정수센터
# 3            3      3        한국방송공사앞           여의서로 한국방송공사앞
# 4            4      4         여의하류IC             노들로 여의하류IC
# 5            5      5            안양교             서부간선도로 안양교
# 6            6      6         유수지주차장            면목천로 유수지주차장
# 7            7      7          이화교동단             중랑천로 이화교동단
# 8            8      8          오금교동측           서부간선도로 오금교동측
# 9            9      9      월드컵파크12단지        월드컵북로 월드컵파크12단지
# 10          10     10   올림픽대로동부간선분기점  테헤란로115길 올림픽대로동부간선분기점
# 11          11     11            창동교             동부간선도로 창동교
# 12          12     12           E-마트               동남로 E-마트
# 13          13     13          워베스빌앞           목동중앙본로 워베스빌앞
# 14          14     14        종합운동장JC           한가람로 종합운동장JC
# 15          15     15           대명초교               상암로 대명초교
# 16          16     16           가양IC             올림픽대로 가양IC
# 17          17     17          용마T/G             용마터널 용마T/G
# 18          18     18          상원삼거리             성수일로 상원삼거리
# 19          19     19          민마루고개             양재대로 민마루고개
#
#                          url  long  lat  실패_인덱스
# 0   http://kko.to/u8zRmeRQJd   NaN  NaN       7
# 1   http://kko.to/StbHDfgnFN   NaN  NaN      21
# 2   http://kko.to/dn_Gnm85oJ   NaN  NaN      37
# 3   http://kko.to/yzK_6dH2ww   NaN  NaN      39
# 4   http://kko.to/9GQduBLMEA   NaN  NaN      44
# 5   http://kko.to/RZf5ImT8PW   NaN  NaN      46
# 6   http://kko.to/27sZDpyT8q   NaN  NaN      49
# 7   http://kko.to/r3sNgdQ0XI   NaN  NaN      58
# 8   http://kko.to/Li1jUcY08j   NaN  NaN      71
# 9   http://kko.to/8lfSPc0kmJ   NaN  NaN      88
# 10  http://kko.to/Lky947e5nD   NaN  NaN      89
# 11  http://kko.to/EuVlzaHjcI   NaN  NaN     101
# 12  http://kko.to/q-YigLwHd1   NaN  NaN     113
# 13  http://kko.to/Gu8cRur72l   NaN  NaN     132
# 14  http://kko.to/L1N8RW8Soq   NaN  NaN     142
# 15  http://kko.to/CbhCf2vwL4   NaN  NaN     196
# 16  http://kko.to/oal8kWiVSu   NaN  NaN     214
# 17  http://kko.to/TqMXV9Z3km   NaN  NaN     216
# 18  http://kko.to/_wqE0_kOf9   NaN  NaN     258
# 19  http://kko.to/llvN5TUes6   NaN  NaN     291

# %%
result = result.set_axis(['A', 'B', '위치', '도로명 포함 주소', 'url', 'long', 'lat', '실패_인덱스'], axis=1)

# %%
result
# Out:
#        A    B                위치                도로명 포함 주소  \
# 0      0    0         우이제3교(북단)           우이천로 우이제3교(북단)
# 1      1    1     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2      2    2            암사정수센터              아리수로 암사정수센터
# 3      3    3           한국방송공사앞             여의서로 한국방송공사앞
# 4      4    4            여의하류IC               노들로 여의하류IC
# ..   ...  ...               ...                      ...
# 220  220  220            잠실3삼거리               삼전로 잠실3삼거리
# 221  221  221            대방천사거리              대방천로 대방천사거리
# 222  222  222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223  223  223            북한남삼거리              이태원로 북한남삼거리
# 224  224  224            북한남삼거리              한남대로 북한남삼거리
#
#                           url  long  lat  실패_인덱스
# 0    http://kko.to/u8zRmeRQJd   NaN  NaN       7
# 1    http://kko.to/StbHDfgnFN   NaN  NaN      21
# 2    http://kko.to/dn_Gnm85oJ   NaN  NaN      37
# 3    http://kko.to/yzK_6dH2ww   NaN  NaN      39
# 4    http://kko.to/9GQduBLMEA   NaN  NaN      44
# ..                        ...   ...  ...     ...
# 220  http://kko.to/yNPtksQ8qu   NaN  NaN    3130
# 221  http://kko.to/iG5tEPnxmM   NaN  NaN    3132
# 222  http://kko.to/Q4AwqSdVsl   NaN  NaN    1875
# 223  http://kko.to/ELeVBpiUyE   NaN  NaN     663
# 224  http://kko.to/ELeVBpiUyE   NaN  NaN    1475
#
# [225 rows x 8 columns]

# %%
result2.to_csv('./카카오 위도 돌림.csv', encoding='EUC-KR', index = False)

# %%
result2 = pd.read_csv('./카카오 위도 돌림.csv', encoding='EUC-KR')

# %%
result2
# Out:
#                    위치                도로명 포함 주소                       url  \
# 0           우이제3교(북단)           우이천로 우이제3교(북단)  http://kko.to/u8zRmeRQJd
# 1       홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)  http://kko.to/StbHDfgnFN
# 2              암사정수센터              아리수로 암사정수센터  http://kko.to/dn_Gnm85oJ
# 3             한국방송공사앞             여의서로 한국방송공사앞  http://kko.to/yzK_6dH2ww
# 4              여의하류IC               노들로 여의하류IC  http://kko.to/9GQduBLMEA
# ..                ...                      ...                       ...
# 220            잠실3삼거리               삼전로 잠실3삼거리  http://kko.to/yNPtksQ8qu
# 221            대방천사거리              대방천로 대방천사거리  http://kko.to/iG5tEPnxmM
# 222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프  http://kko.to/Q4AwqSdVsl
# 223            북한남삼거리              이태원로 북한남삼거리  http://kko.to/ELeVBpiUyE
# 224            북한남삼거리              한남대로 북한남삼거리  http://kko.to/ELeVBpiUyE
#
#      long  lat  실패_인덱스
# 0     NaN  NaN       7
# 1     NaN  NaN      21
# 2     NaN  NaN      37
# 3     NaN  NaN      39
# 4     NaN  NaN      44
# ..    ...  ...     ...
# 220   NaN  NaN    3130
# 221   NaN  NaN    3132
# 222   NaN  NaN    1875
# 223   NaN  NaN     663
# 224   NaN  NaN    1475
#
# [225 rows x 6 columns]

# %%
url_list = result2['url']

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup
import time
from tqdm import tqdm

# %%
chrome_options = webdriver.ChromeOptions()

url = "https://xn--yq5bk9r.com/blog/map-coordinates"
driver = webdriver.Chrome(service=Service("./driver/chromedriver.exe"), options=chrome_options)
driver.get(url)

# %%
css_selector = '''#__next > div > div > main > div.mx-auto.max-w-3xl.px-4.sm\:px-6.xl\:max-w-5xl.xl\:px-0 > article > div > div > div > div.prose.max-w-none.pt-10.pb-8.dark\:prose-dark > div > div.flex.flex-col.space-y-4 > div.flex.flex-col.space-y-4 > input'''
search_docs = driver.find_element(By.CSS_SELECTOR, css_selector).send_keys(url_list[0]) 
time.sleep(1.0)

xpath ='//*[@id="__next"]/div/div/main/div[3]/article/div/div/div/div[1]/div/div[2]/div[1]/button'
search_btn = driver.find_element(By.XPATH, xpath).click()
time.sleep(3.0)

Xpath = '//*[@id="__next"]/div/div/main/div[3]/article/div/div/div/div[1]/div/div[2]/div[2]/div/div[1]/text()[2]'
text = driver.find_element(By.XPATH, xpath)

req = driver.page_source
soup = BeautifulSoup(req, 'html.parser')

gage = soup.find_all(class_ = "flex flex-col space-y-4")

gage_text = gage[0].text
gage_split = gage_text.split(" ")

search_docs = driver.find_element(By.CSS_SELECTOR, css_selector).clear()
time.sleep(0.5)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8090dca1506f81c1cd4be64fd25ffa7f", element="4a9682ac-787e-4e4e-8063-969366996292")>

# %%
gage_split[10]
# Out:
# '37.63690855660938,'

# %%
gage_split[13]
# Out:
# '127.03644984634987'

# %%
for i in tqdm(range(len(result2))):
    css_selector = '''#__next > div > div > main > div.mx-auto.max-w-3xl.px-4.sm\:px-6.xl\:max-w-5xl.xl\:px-0 > article > div > div > div > div.prose.max-w-none.pt-10.pb-8.dark\:prose-dark > div > div.flex.flex-col.space-y-4 > div.flex.flex-col.space-y-4 > input'''
    search_docs = driver.find_element(By.CSS_SELECTOR, css_selector).send_keys(url_list[i]) 
    time.sleep(1.0)

    xpath ='//*[@id="__next"]/div/div/main/div[3]/article/div/div/div/div[1]/div/div[2]/div[1]/button'
    search_btn = driver.find_element(By.XPATH, xpath).click()
    time.sleep(3.0)

    Xpath = '//*[@id="__next"]/div/div/main/div[3]/article/div/div/div/div[1]/div/div[2]/div[2]/div/div[1]/text()[2]'
    text = driver.find_element(By.XPATH, xpath)

    req = driver.page_source
    soup = BeautifulSoup(req, 'html.parser')

    gage = soup.find_all(class_ = "flex flex-col space-y-4")

    gage_text = gage[0].text
    gage_split = gage_text.split(" ")
    result2['lat'][i] = gage_split[10]
    result2['long'][i] = gage_split[13]

    search_docs = driver.find_element(By.CSS_SELECTOR, css_selector).clear()
    time.sleep(0.5)
# Out:
#   0%|                                                                                          | 0/225 [00:00<?, ?it/s]C:\Users\김두엽\AppData\Local\Temp\ipykernel_11460\1169430526.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result2['lat'][i] = gage_split[10]
# C:\Users\김두엽\AppData\Local\Temp\ipykernel_11460\1169430526.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result2['long'][i] = gage_split[13]
# 100%|████████████████████████████████████████████████████████████████████████████████| 225/225 [17:21<00:00,  4.63s/it]

# %%
result2.to_csv('./누락수정.csv', encoding='EUC-KR', index=False)
