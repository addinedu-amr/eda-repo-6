# %%
import pandas as pd

# %%
speed_location = pd.read_csv('./speed_location_first.csv', encoding='EUC-KR')
speed_location
# Out:
#              위치         도로명 포함 주소        long        lat
# 0        남부교육청앞      버드나루로 남부교육청앞  126.895507  37.519400
# 1        혜화동로터리       창경궁로 혜화동로터리  127.001217  37.585533
# 2           강변역          강변역로 강변역  127.094695  37.535098
# 3      신한은행암사지점  올림픽로98길 신한은행암사지점  127.129245  37.550553
# 4       이촌동두산위브    이촌로51길 이촌동두산위브  126.966070  37.516122
# ...         ...               ...         ...        ...
# 3129       증산3교         거북골로 증산3교  126.906310  37.580087
# 3130     잠실3삼거리        삼전로 잠실3삼거리         NaN        NaN
# 3131    마장동주민센터       마장로 마장동주민센터  127.045393  37.566281
# 3132     대방천사거리       대방천로 대방천사거리         NaN        NaN
# 3133  방화119안전센터    금낭화로 방화119안전센터  126.814263  37.579752
#
# [3134 rows x 4 columns]

# %%
speed_location = speed_location.fillna(0)
speed_location
# Out:
#              위치         도로명 포함 주소        long        lat
# 0        남부교육청앞      버드나루로 남부교육청앞  126.895507  37.519400
# 1        혜화동로터리       창경궁로 혜화동로터리  127.001217  37.585533
# 2           강변역          강변역로 강변역  127.094695  37.535098
# 3      신한은행암사지점  올림픽로98길 신한은행암사지점  127.129245  37.550553
# 4       이촌동두산위브    이촌로51길 이촌동두산위브  126.966070  37.516122
# ...         ...               ...         ...        ...
# 3129       증산3교         거북골로 증산3교  126.906310  37.580087
# 3130     잠실3삼거리        삼전로 잠실3삼거리    0.000000   0.000000
# 3131    마장동주민센터       마장로 마장동주민센터  127.045393  37.566281
# 3132     대방천사거리       대방천로 대방천사거리    0.000000   0.000000
# 3133  방화119안전센터    금낭화로 방화119안전센터  126.814263  37.579752
#
# [3134 rows x 4 columns]

# %%
a = speed_location[speed_location['long'] <= 120]
a
# Out:
#                  위치            도로명 포함 주소       long      lat
# 7         우이제3교(북단)       우이천로 우이제3교(북단)  15.061587 -7.61021
# 21    홍은램프진입(내부순환로)  내부순환로 홍은램프진입(내부순환로)   0.000000  0.00000
# 37           암사정수센터          아리수로 암사정수센터   0.000000  0.00000
# 39          한국방송공사앞         여의서로 한국방송공사앞   0.000000  0.00000
# 44           여의하류IC           노들로 여의하류IC   0.000000  0.00000
# ...             ...                  ...        ...      ...
# 3081           영남교회             영신로 영남교회   0.000000  0.00000
# 3104          신정교서단            신목로 신정교서단   0.000000  0.00000
# 3120          기상청입구          여의대방로 기상청입구   0.000000  0.00000
# 3130         잠실3삼거리           삼전로 잠실3삼거리   0.000000  0.00000
# 3132         대방천사거리          대방천로 대방천사거리   0.000000  0.00000
#
# [222 rows x 4 columns]

# %%
b = speed_location[speed_location['lat'] <= 30]
b
# Out:
#                  위치            도로명 포함 주소       long      lat
# 7         우이제3교(북단)       우이천로 우이제3교(북단)  15.061587 -7.61021
# 21    홍은램프진입(내부순환로)  내부순환로 홍은램프진입(내부순환로)   0.000000  0.00000
# 37           암사정수센터          아리수로 암사정수센터   0.000000  0.00000
# 39          한국방송공사앞         여의서로 한국방송공사앞   0.000000  0.00000
# 44           여의하류IC           노들로 여의하류IC   0.000000  0.00000
# ...             ...                  ...        ...      ...
# 3081           영남교회             영신로 영남교회   0.000000  0.00000
# 3104          신정교서단            신목로 신정교서단   0.000000  0.00000
# 3120          기상청입구          여의대방로 기상청입구   0.000000  0.00000
# 3130         잠실3삼거리           삼전로 잠실3삼거리   0.000000  0.00000
# 3132         대방천사거리          대방천로 대방천사거리   0.000000  0.00000
#
# [218 rows x 4 columns]

# %%
c = speed_location[speed_location['long'] >= 130]
c
# Out:
#                     위치                도로명 포함 주소        long        lat
# 1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프  140.784558  36.888733

# %%
d = speed_location[speed_location['lat'] >= 40]
d
# Out:
#           위치     도로명 포함 주소        long        lat
# 132    워베스빌앞  목동중앙본로 워베스빌앞   15.621290  53.639180
# 663   북한남삼거리   이태원로 북한남삼거리  127.510093  40.339852
# 1475  북한남삼거리   한남대로 북한남삼거리  127.510093  40.339852
# 2339   역사박물관    종로1길 역사박물관   26.865283  50.292491
# 2929   역사박물관   사직로8길 역사박물관   26.865283  50.292491

# %% [markdown]
# # 다음의 값들은 실패한 값이다. 이는 셀레니움으로 해결보자.
# # 일단 데이터를 삭제해야한다.

# %%
result1 = pd.concat([a, b, c, d])
result2 = result1.drop_duplicates()
result2
# Out:
#                     위치                도로명 포함 주소        long        lat
# 7            우이제3교(북단)           우이천로 우이제3교(북단)   15.061587  -7.610210
# 21       홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)    0.000000   0.000000
# 37              암사정수센터              아리수로 암사정수센터    0.000000   0.000000
# 39             한국방송공사앞             여의서로 한국방송공사앞    0.000000   0.000000
# 44              여의하류IC               노들로 여의하류IC    0.000000   0.000000
# ...                ...                      ...         ...        ...
# 3130            잠실3삼거리               삼전로 잠실3삼거리    0.000000   0.000000
# 3132            대방천사거리              대방천로 대방천사거리    0.000000   0.000000
# 1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프  140.784558  36.888733
# 663             북한남삼거리              이태원로 북한남삼거리  127.510093  40.339852
# 1475            북한남삼거리              한남대로 북한남삼거리  127.510093  40.339852
#
# [225 rows x 4 columns]

# %%
result_reset_inext =result2.reset_index()

# %%
result_reset_inext
# Out:
#      index                위치                도로명 포함 주소        long        lat
# 0        7         우이제3교(북단)           우이천로 우이제3교(북단)   15.061587  -7.610210
# 1       21     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)    0.000000   0.000000
# 2       37            암사정수센터              아리수로 암사정수센터    0.000000   0.000000
# 3       39           한국방송공사앞             여의서로 한국방송공사앞    0.000000   0.000000
# 4       44            여의하류IC               노들로 여의하류IC    0.000000   0.000000
# ..     ...               ...                      ...         ...        ...
# 220   3130            잠실3삼거리               삼전로 잠실3삼거리    0.000000   0.000000
# 221   3132            대방천사거리              대방천로 대방천사거리    0.000000   0.000000
# 222   1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프  140.784558  36.888733
# 223    663            북한남삼거리              이태원로 북한남삼거리  127.510093  40.339852
# 224   1475            북한남삼거리              한남대로 북한남삼거리  127.510093  40.339852
#
# [225 rows x 5 columns]

# %%
result_reset_inext = result_reset_inext.drop(['long', 'lat'], axis=1)
result_reset_inext
# Out:
#      index                위치                도로명 포함 주소
# 0        7         우이제3교(북단)           우이천로 우이제3교(북단)
# 1       21     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2       37            암사정수센터              아리수로 암사정수센터
# 3       39           한국방송공사앞             여의서로 한국방송공사앞
# 4       44            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...
# 220   3130            잠실3삼거리               삼전로 잠실3삼거리
# 221   3132            대방천사거리              대방천로 대방천사거리
# 222   1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    663            북한남삼거리              이태원로 북한남삼거리
# 224   1475            북한남삼거리              한남대로 북한남삼거리
#
# [225 rows x 3 columns]

# %%
result_reset_inext['url'] = ""
result_reset_inext['long'] = ""
result_reset_inext['lat'] = ""

# %%
result_reset_inext
# Out:
#      index                위치                도로명 포함 주소 url long lat
# 0        7         우이제3교(북단)           우이천로 우이제3교(북단)
# 1       21     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2       37            암사정수센터              아리수로 암사정수센터
# 3       39           한국방송공사앞             여의서로 한국방송공사앞
# 4       44            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...  ..  ...  ..
# 220   3130            잠실3삼거리               삼전로 잠실3삼거리
# 221   3132            대방천사거리              대방천로 대방천사거리
# 222   1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    663            북한남삼거리              이태원로 북한남삼거리
# 224   1475            북한남삼거리              한남대로 북한남삼거리
#
# [225 rows x 6 columns]

# %%
result_reset_inext.to_csv('./fail_list_sele.csv', encoding='EUC-KR')

# %% [markdown]
# # 셀레니움을 진행하려고 합니다.
# https://dday.tistory.com/616

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup
import time
from tqdm import tqdm

# %% [markdown]
# # 일단 위치정보로 뽑아볼게요.

# %%
result_index_list = result_reset_inext['index'].to_list()
result_address_list =  result_reset_inext['위치'].to_list()

# %%
result_address_list_setting = []
for i in range(len(result_address_list)):
    result_address_list_split = result_address_list[i].split('(')
    result_address_list_setting.append(result_address_list_split[0])
result_address_list_setting
# Out:
# ['우이제3교',
#  '홍은램프진입',
#  '암사정수센터',
#  '한국방송공사앞',
#  '여의하류IC',
#  '안양교',
#  '유수지주차장',
#  '이화교동단',
#  '오금교동측',
#  '월드컵파크12단지',
#  '올림픽대로동부간선분기점',
#  '창동교',
#  'E-마트',
#  '워베스빌앞',
#  '종합운동장JC',
#  '대명초교',
#  '가양IC',
#  '용마T/G',
#  '상원삼거리',
#  '민마루고개',
#  '마장램프',
#  '경인고속입구',
#  '유수지주차장',
#  '우성아파트',
#  '성산분기점',
#  '강북구선거관리위윈회',
#  '동부간선도로수락분기점',
#  '증산교',
#  '용마터널',
#  '원효동산호아파트',
#  '탄천1교동측',
#  '안중근의사기념관',
#  '상암사거리',
#  '금천교교차로',
#  '상계교',
#  '암사IC',
#  '한스타워',
#  '호암길삼거리',
#  '서울지방경찰청',
#  '종합운동장JC',
#  '래미안아트힐',
#  '근로자회관',
#  '난지도종합처리',
#  '대우드림빌앞',
#  '길음램프',
#  '월계라이프아파트',
#  '상수진출입',
#  '탄천1교동측',
#  '증산교',
#  '외발산사거리',
#  '일진빌딩',
#  '만능카종합공업사',
#  '쌍마빌딩',
#  '창의문앞',
#  '청담IC',
#  '광교',
#  '암사정수센터',
#  '번창교',
#  '천호신사거리',
#  '여의상류IC',
#  '사근램프',
#  '생명의전화',
#  '과학수사연구소입구',
#  '원일빌딩',
#  '성산진입램프',
#  '서초구립반포도서관',
#  '국기원앞',
#  '안중근의사기념관',
#  'CITY극동아파트103동앞',
#  '등촌동현대아파트',
#  '한남고가차도남단',
#  '동부간선도로-강변북로램프',
#  '여의상류IC',
#  '내부순환로입구교차로',
#  '양천소방서',
#  '의원회관앞',
#  '월릉교동측',
#  '남부순환로탄천IC진입',
#  '북악산로입구',
#  '탄천1교동측',
#  'KT연구개발본부',
#  '내부순환로연결램프',
#  '당현초교',
#  '청계9가',
#  '여의하류IC',
#  '청계8가',
#  '도동삼거리',
#  '고덕삼환아파트',
#  '도림펌프장앞',
#  '북악산로입구',
#  '고덕근린공원',
#  '서이초교',
#  '장지교차로',
#  '스카이뷰아파트',
#  '증산교',
#  '고덕소방파출소',
#  '청계6가',
#  '이마트',
#  '근로자회관',
#  '청담IC',
#  '신정빗물펌프장',
#  '차관아파트',
#  '주공6단지',
#  '종합운동장후문',
#  '양천소방서',
#  '2공단사거리',
#  '당현초교',
#  '강월초교',
#  '서울메트로',
#  '한강시민공원양화지구',
#  '성산1교',
#  '고척2파출소앞',
#  '고속터미널역',
#  '외발산사거리',
#  '탄천1교서측',
#  '삼표레미콘',
#  '고척2파출소앞',
#  '월계1교동측',
#  '신진빌딩',
#  '여의JCT',
#  '청계3가',
#  '수유5동사무소',
#  '탄천1교서측',
#  '동부간선도로-월계로램프',
#  '열병합발전소',
#  '시계',
#  '도동삼거리',
#  '경서농협개봉역지점',
#  '초안산지하차도',
#  '2공단사거리',
#  '한국전력동부지점',
#  '금천교남단',
#  '양동초교입구',
#  '동1로의정부시계',
#  '개화동로진입',
#  '명덕초교',
#  '산업안전협회',
#  '효령아파트',
#  '상봉시장앞',
#  '이마트',
#  '올림픽대로시점',
#  '동부간선강변북로분기점',
#  '동아일보하단',
#  '한성빌라',
#  '난지IC',
#  '녹천지하보차도',
#  '상계교',
#  '삼성테마트',
#  '모래내지하차도',
#  '대우드림타운',
#  '독산3동주민센터',
#  '개봉지하차도',
#  '위례1지하차도',
#  '경인고속입구',
#  '신정교서단',
#  '당현2교',
#  '연희램프',
#  '월릉IC',
#  '대방교',
#  '역사박물관',
#  '청계6가앞',
#  '금천교교차로',
#  '홍은램프',
#  '서부간선요금소',
#  '금호빌딩',
#  '장지교',
#  '온수골사거리',
#  '금천교',
#  '청계2가',
#  '홍제램프',
#  '영동2교북단',
#  '현대3차아파트',
#  '동일초교',
#  '강일5.7단지',
#  '고속터미널',
#  '동부간선도로강변북로분기점',
#  'e-테크벨리오피스텔',
#  '남부순환로탄천IC합류',
#  '교대입구',
#  '시계',
#  '능산삼거리',
#  '동부간선도로수락분기점',
#  '당현2교',
#  '영남교회',
#  '상계교',
#  '국회북문',
#  '보라매공원',
#  'KT연구개발본부',
#  '성산램프',
#  '2공단사거리',
#  '암사IC',
#  '이화교동단',
#  '세종대로사거리',
#  '신정교동단',
#  '극동방송국',
#  '신월요금소',
#  '암사정수센터',
#  '세종대로사거리',
#  '온수골사거리',
#  '국민일보',
#  '증산교',
#  '신정교서단',
#  '신정교동단',
#  '동부간선도로강변북로분기점',
#  '박석고개',
#  '동부간선도로-월계로램프',
#  '역사박물관',
#  '뚝섬정수장앞',
#  '선암UD',
#  '올림픽대로동부간선JC',
#  '어린이교통공원',
#  '수출입은행뒤',
#  '삼흥자동차공업사',
#  '효자삼거리',
#  '선암영업소',
#  '동부제강입구',
#  '위례파출소',
#  '영남교회',
#  '신정교서단',
#  '기상청입구',
#  '잠실3삼거리',
#  '대방천사거리',
#  '동부간선도로-일반국도6호선램프',
#  '북한남삼거리',
#  '북한남삼거리']

# %%
for i in range(len(result_address_list_setting)):
    result_address_list_setting[i] = result_address_list_setting[i].replace("진입", "")
    result_address_list_setting[i] = "서울 " + result_address_list_setting[i] 
result_address_list_setting
# Out:
# ['서울 우이제3교',
#  '서울 홍은램프',
#  '서울 암사정수센터',
#  '서울 한국방송공사앞',
#  '서울 여의하류IC',
#  '서울 안양교',
#  '서울 유수지주차장',
#  '서울 이화교동단',
#  '서울 오금교동측',
#  '서울 월드컵파크12단지',
#  '서울 올림픽대로동부간선분기점',
#  '서울 창동교',
#  '서울 E-마트',
#  '서울 워베스빌앞',
#  '서울 종합운동장JC',
#  '서울 대명초교',
#  '서울 가양IC',
#  '서울 용마T/G',
#  '서울 상원삼거리',
#  '서울 민마루고개',
#  '서울 마장램프',
#  '서울 경인고속입구',
#  '서울 유수지주차장',
#  '서울 우성아파트',
#  '서울 성산분기점',
#  '서울 강북구선거관리위윈회',
#  '서울 동부간선도로수락분기점',
#  '서울 증산교',
#  '서울 용마터널',
#  '서울 원효동산호아파트',
#  '서울 탄천1교동측',
#  '서울 안중근의사기념관',
#  '서울 상암사거리',
#  '서울 금천교교차로',
#  '서울 상계교',
#  '서울 암사IC',
#  '서울 한스타워',
#  '서울 호암길삼거리',
#  '서울 서울지방경찰청',
#  '서울 종합운동장JC',
#  '서울 래미안아트힐',
#  '서울 근로자회관',
#  '서울 난지도종합처리',
#  '서울 대우드림빌앞',
#  '서울 길음램프',
#  '서울 월계라이프아파트',
#  '서울 상수진출입',
#  '서울 탄천1교동측',
#  '서울 증산교',
#  '서울 외발산사거리',
#  '서울 일진빌딩',
#  '서울 만능카종합공업사',
#  '서울 쌍마빌딩',
#  '서울 창의문앞',
#  '서울 청담IC',
#  '서울 광교',
#  '서울 암사정수센터',
#  '서울 번창교',
#  '서울 천호신사거리',
#  '서울 여의상류IC',
#  '서울 사근램프',
#  '서울 생명의전화',
#  '서울 과학수사연구소입구',
#  '서울 원일빌딩',
#  '서울 성산램프',
#  '서울 서초구립반포도서관',
#  '서울 국기원앞',
#  '서울 안중근의사기념관',
#  '서울 CITY극동아파트103동앞',
#  '서울 등촌동현대아파트',
#  '서울 한남고가차도남단',
#  '서울 동부간선도로-강변북로램프',
#  '서울 여의상류IC',
#  '서울 내부순환로입구교차로',
#  '서울 양천소방서',
#  '서울 의원회관앞',
#  '서울 월릉교동측',
#  '서울 남부순환로탄천IC',
#  '서울 북악산로입구',
#  '서울 탄천1교동측',
#  '서울 KT연구개발본부',
#  '서울 내부순환로연결램프',
#  '서울 당현초교',
#  '서울 청계9가',
#  '서울 여의하류IC',
#  '서울 청계8가',
#  '서울 도동삼거리',
#  '서울 고덕삼환아파트',
#  '서울 도림펌프장앞',
#  '서울 북악산로입구',
#  '서울 고덕근린공원',
#  '서울 서이초교',
#  '서울 장지교차로',
#  '서울 스카이뷰아파트',
#  '서울 증산교',
#  '서울 고덕소방파출소',
#  '서울 청계6가',
#  '서울 이마트',
#  '서울 근로자회관',
#  '서울 청담IC',
#  '서울 신정빗물펌프장',
#  '서울 차관아파트',
#  '서울 주공6단지',
#  '서울 종합운동장후문',
#  '서울 양천소방서',
#  '서울 2공단사거리',
#  '서울 당현초교',
#  '서울 강월초교',
#  '서울 서울메트로',
#  '서울 한강시민공원양화지구',
#  '서울 성산1교',
#  '서울 고척2파출소앞',
#  '서울 고속터미널역',
#  '서울 외발산사거리',
#  '서울 탄천1교서측',
#  '서울 삼표레미콘',
#  '서울 고척2파출소앞',
#  '서울 월계1교동측',
#  '서울 신진빌딩',
#  '서울 여의JCT',
#  '서울 청계3가',
#  '서울 수유5동사무소',
#  '서울 탄천1교서측',
#  '서울 동부간선도로-월계로램프',
#  '서울 열병합발전소',
#  '서울 시계',
#  '서울 도동삼거리',
#  '서울 경서농협개봉역지점',
#  '서울 초안산지하차도',
#  '서울 2공단사거리',
#  '서울 한국전력동부지점',
#  '서울 금천교남단',
#  '서울 양동초교입구',
#  '서울 동1로의정부시계',
#  '서울 개화동로',
#  '서울 명덕초교',
#  '서울 산업안전협회',
#  '서울 효령아파트',
#  '서울 상봉시장앞',
#  '서울 이마트',
#  '서울 올림픽대로시점',
#  '서울 동부간선강변북로분기점',
#  '서울 동아일보하단',
#  '서울 한성빌라',
#  '서울 난지IC',
#  '서울 녹천지하보차도',
#  '서울 상계교',
#  '서울 삼성테마트',
#  '서울 모래내지하차도',
#  '서울 대우드림타운',
#  '서울 독산3동주민센터',
#  '서울 개봉지하차도',
#  '서울 위례1지하차도',
#  '서울 경인고속입구',
#  '서울 신정교서단',
#  '서울 당현2교',
#  '서울 연희램프',
#  '서울 월릉IC',
#  '서울 대방교',
#  '서울 역사박물관',
#  '서울 청계6가앞',
#  '서울 금천교교차로',
#  '서울 홍은램프',
#  '서울 서부간선요금소',
#  '서울 금호빌딩',
#  '서울 장지교',
#  '서울 온수골사거리',
#  '서울 금천교',
#  '서울 청계2가',
#  '서울 홍제램프',
#  '서울 영동2교북단',
#  '서울 현대3차아파트',
#  '서울 동일초교',
#  '서울 강일5.7단지',
#  '서울 고속터미널',
#  '서울 동부간선도로강변북로분기점',
#  '서울 e-테크벨리오피스텔',
#  '서울 남부순환로탄천IC합류',
#  '서울 교대입구',
#  '서울 시계',
#  '서울 능산삼거리',
#  '서울 동부간선도로수락분기점',
#  '서울 당현2교',
#  '서울 영남교회',
#  '서울 상계교',
#  '서울 국회북문',
#  '서울 보라매공원',
#  '서울 KT연구개발본부',
#  '서울 성산램프',
#  '서울 2공단사거리',
#  '서울 암사IC',
#  '서울 이화교동단',
#  '서울 세종대로사거리',
#  '서울 신정교동단',
#  '서울 극동방송국',
#  '서울 신월요금소',
#  '서울 암사정수센터',
#  '서울 세종대로사거리',
#  '서울 온수골사거리',
#  '서울 국민일보',
#  '서울 증산교',
#  '서울 신정교서단',
#  '서울 신정교동단',
#  '서울 동부간선도로강변북로분기점',
#  '서울 박석고개',
#  '서울 동부간선도로-월계로램프',
#  '서울 역사박물관',
#  '서울 뚝섬정수장앞',
#  '서울 선암UD',
#  '서울 올림픽대로동부간선JC',
#  '서울 어린이교통공원',
#  '서울 수출입은행뒤',
#  '서울 삼흥자동차공업사',
#  '서울 효자삼거리',
#  '서울 선암영업소',
#  '서울 동부제강입구',
#  '서울 위례파출소',
#  '서울 영남교회',
#  '서울 신정교서단',
#  '서울 기상청입구',
#  '서울 잠실3삼거리',
#  '서울 대방천사거리',
#  '서울 동부간선도로-일반국도6호선램프',
#  '서울 북한남삼거리',
#  '서울 북한남삼거리']

# %%
chrome_options = webdriver.ChromeOptions()

url = "https://map.kakao.com/"
driver = webdriver.Chrome(service=Service("./driver/chromedriver.exe"), options=chrome_options)
driver.get(url)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## 로봇방지로 들어가 있는 요소로 보인다. 해결하고 싶으나 방법이 없다.
# ## 그러니 필수적으로 카카오지도를 열고 나서
# ## 수동으로 지도를 클릭해줘야한다.

# %%
result_reset_inext_2 = result_reset_inext
result_reset_inext_2
# Out:
#      index                위치                도로명 포함 주소 url long lat
# 0        7         우이제3교(북단)           우이천로 우이제3교(북단)
# 1       21     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2       37            암사정수센터              아리수로 암사정수센터
# 3       39           한국방송공사앞             여의서로 한국방송공사앞
# 4       44            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...  ..  ...  ..
# 220   3130            잠실3삼거리               삼전로 잠실3삼거리
# 221   3132            대방천사거리              대방천로 대방천사거리
# 222   1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    663            북한남삼거리              이태원로 북한남삼거리
# 224   1475            북한남삼거리              한남대로 북한남삼거리
#
# [225 rows x 6 columns]

# %%
result_reset_inext_2
# Out:
#      index                위치                도로명 포함 주소 url long lat
# 0        7         우이제3교(북단)           우이천로 우이제3교(북단)
# 1       21     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2       37            암사정수센터              아리수로 암사정수센터
# 3       39           한국방송공사앞             여의서로 한국방송공사앞
# 4       44            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...  ..  ...  ..
# 220   3130            잠실3삼거리               삼전로 잠실3삼거리
# 221   3132            대방천사거리              대방천로 대방천사거리
# 222   1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    663            북한남삼거리              이태원로 북한남삼거리
# 224   1475            북한남삼거리              한남대로 북한남삼거리
#
# [225 rows x 6 columns]

# %% [markdown]
# # 중간에 메크로 방지가 나오기 때문에 time.sleep을 길게 줘야할거같음
# - 일단 내 예상으로는 30개 마다 나오는 것으로 보임

# %%
fail_index = []
adress = []
road_adress = []

for i in tqdm(range(len(result_address_list_setting))):
    css_selector = '''#search\.keyword\.query'''
    search_docs = driver.find_element(By.CSS_SELECTOR, css_selector).send_keys(result_address_list_setting[i] + Keys.ENTER) 
    time.sleep(0.5)
   
    try:
        searh_result = driver.find_element(By.CLASS_NAME, "tit_name").click()
        time.sleep(0.5)


        searh_result = driver.find_element(By.CLASS_NAME, "tit_tool").click()
        time.sleep(0.5)


        searh_result = driver.find_element(By.ID, "tool.map.copyurl").click()
        time.sleep(0.5)

        result_reset_inext_2['url'][i] =  driver.find_element(By.CLASS_NAME, "txt_url").text

        xpath_search_result = '''//*[@id="shareUrl"]/div/div[1]/button/span'''
        search_btn = driver.find_element(By.XPATH, xpath_search_result).click()
        time.sleep(0.5)
    
    except:
        print('카카오로도 해결할 수 없다.')
        fail_index.append(i)
        adress.append(result_reset_inext['위치'][i])
        road_adress.append(result_reset_inext['도로명 포함 주소'][i])
    
    search_docs = driver.find_element(By.CSS_SELECTOR, css_selector).clear()
    time.sleep(0.5)
    
    # 메크로 방지를 위해서 손이 한 번 들어가야함.
    if i == 20:
        print("지도를 터치하세요.")
        time.sleep(10)

result_reset_inext_2
# Out:
#   0%|                                                                                          | 0/225 [00:00<?, ?it/s]C:\Users\김두엽\AppData\Local\Temp\ipykernel_4060\3083460792.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_reset_inext_2['url'][i] =  driver.find_element(By.CLASS_NAME, "txt_url").text
#   2%|█▊                                                                                | 5/225 [00:16<11:45,  3.21s/it]
# 카카오로도 해결할 수 없다.
#   3%|██▌                                                                               | 7/225 [00:20<09:52,  2.72s/it]
# 카카오로도 해결할 수 없다.
#   4%|██▉                                                                               | 8/225 [00:21<07:55,  2.19s/it]
# 카카오로도 해결할 수 없다.
#   4%|███▌                                                                             | 10/225 [00:25<08:05,  2.26s/it]
# 카카오로도 해결할 수 없다.
#   6%|████▋                                                                            | 13/225 [00:33<09:05,  2.57s/it]
# 카카오로도 해결할 수 없다.
#   8%|██████                                                                           | 17/225 [00:43<09:49,  2.83s/it]
# 카카오로도 해결할 수 없다.
#   8%|██████▊                                                                          | 19/225 [00:48<08:49,  2.57s/it]
# 카카오로도 해결할 수 없다.
#   9%|███████▏                                                                         | 20/225 [00:49<07:13,  2.12s/it]
# 지도를 터치하세요.
#  11%|█████████                                                                        | 25/225 [01:15<12:29,  3.75s/it]
# 카카오로도 해결할 수 없다.
#  12%|█████████▎                                                                       | 26/225 [01:16<09:46,  2.95s/it]
# 카카오로도 해결할 수 없다.
#  12%|██████████                                                                       | 28/225 [01:20<08:39,  2.64s/it]
# 카카오로도 해결할 수 없다.
#  13%|██████████▍                                                                      | 29/225 [01:21<07:04,  2.17s/it]
# 카카오로도 해결할 수 없다.
#  13%|██████████▊                                                                      | 30/225 [01:22<05:58,  1.84s/it]
# 카카오로도 해결할 수 없다.
#  16%|█████████████▎                                                                   | 37/225 [01:42<09:24,  3.00s/it]
# 카카오로도 해결할 수 없다.
#  19%|███████████████                                                                  | 42/225 [01:56<09:12,  3.02s/it]
# 카카오로도 해결할 수 없다.
#  19%|███████████████▍                                                                 | 43/225 [01:57<07:23,  2.43s/it]
# 카카오로도 해결할 수 없다.
#  20%|████████████████▌                                                                | 46/225 [02:05<07:48,  2.62s/it]
# 카카오로도 해결할 수 없다.
#  21%|████████████████▉                                                                | 47/225 [02:06<06:23,  2.15s/it]
# 카카오로도 해결할 수 없다.
#  26%|████████████████████▉                                                            | 58/225 [02:39<08:46,  3.15s/it]
# 카카오로도 해결할 수 없다.
#  30%|████████████████████████▍                                                        | 68/225 [03:09<08:16,  3.16s/it]
# 카카오로도 해결할 수 없다.
#  32%|█████████████████████████▌                                                       | 71/225 [03:16<07:21,  2.87s/it]
# 카카오로도 해결할 수 없다.
#  34%|███████████████████████████▎                                                     | 76/225 [03:30<07:23,  2.98s/it]
# 카카오로도 해결할 수 없다.
#  34%|███████████████████████████▋                                                     | 77/225 [03:31<05:56,  2.41s/it]
# 카카오로도 해결할 수 없다.
#  35%|████████████████████████████                                                     | 78/225 [03:32<04:55,  2.01s/it]
# 카카오로도 해결할 수 없다.
#  35%|████████████████████████████▍                                                    | 79/225 [03:33<04:11,  1.72s/it]
# 카카오로도 해결할 수 없다.
#  36%|█████████████████████████████▏                                                   | 81/225 [03:38<04:52,  2.03s/it]
# 카카오로도 해결할 수 없다.
#  39%|███████████████████████████████▋                                                 | 88/225 [03:58<06:56,  3.04s/it]
# 카카오로도 해결할 수 없다.
#  40%|████████████████████████████████                                                 | 89/225 [03:59<05:33,  2.45s/it]
# 카카오로도 해결할 수 없다.
#  42%|█████████████████████████████████▊                                               | 94/225 [04:13<06:23,  2.92s/it]
# 카카오로도 해결할 수 없다.
#  46%|████████████████████████████████████▌                                           | 103/225 [04:41<06:27,  3.18s/it]
# 카카오로도 해결할 수 없다.
#  47%|█████████████████████████████████████▎                                          | 105/225 [04:45<05:28,  2.74s/it]
# 카카오로도 해결할 수 없다.
#  51%|████████████████████████████████████████▌                                       | 114/225 [05:12<05:49,  3.15s/it]
# 카카오로도 해결할 수 없다.
#  52%|█████████████████████████████████████████▌                                      | 117/225 [05:19<05:08,  2.86s/it]
# 카카오로도 해결할 수 없다.
#  52%|█████████████████████████████████████████▉                                      | 118/225 [05:20<04:08,  2.32s/it]
# 카카오로도 해결할 수 없다.
#  53%|██████████████████████████████████████████▎                                     | 119/225 [05:22<03:59,  2.26s/it]
# 카카오로도 해결할 수 없다.
#  54%|███████████████████████████████████████████▍                                    | 122/225 [05:30<04:24,  2.57s/it]
# 카카오로도 해결할 수 없다.
#  55%|███████████████████████████████████████████▋                                    | 123/225 [05:31<03:36,  2.12s/it]
# 카카오로도 해결할 수 없다.
#  57%|█████████████████████████████████████████████▊                                  | 129/225 [05:48<04:45,  2.97s/it]
# 카카오로도 해결할 수 없다.
#  58%|██████████████████████████████████████████████▌                                 | 131/225 [05:52<04:08,  2.65s/it]
# 카카오로도 해결할 수 없다.
#  59%|███████████████████████████████████████████████▎                                | 133/225 [05:57<03:47,  2.48s/it]
# 카카오로도 해결할 수 없다.
#  62%|█████████████████████████████████████████████████▊                              | 140/225 [06:17<04:20,  3.07s/it]
# 카카오로도 해결할 수 없다.
#  63%|██████████████████████████████████████████████████▏                             | 141/225 [06:18<03:27,  2.47s/it]
# 카카오로도 해결할 수 없다.
#  63%|██████████████████████████████████████████████████▍                             | 142/225 [06:19<02:50,  2.05s/it]
# 카카오로도 해결할 수 없다.
#  64%|███████████████████████████████████████████████████▏                            | 144/225 [06:23<02:57,  2.20s/it]
# 카카오로도 해결할 수 없다.
#  70%|████████████████████████████████████████████████████████▏                       | 158/225 [07:06<03:33,  3.18s/it]
# 카카오로도 해결할 수 없다.
#  76%|████████████████████████████████████████████████████████████▍                   | 170/225 [07:42<02:55,  3.19s/it]
# 카카오로도 해결할 수 없다.
#  77%|█████████████████████████████████████████████████████████████▌                  | 173/225 [07:50<02:30,  2.89s/it]
# 카카오로도 해결할 수 없다.
#  78%|██████████████████████████████████████████████████████████████▏                 | 175/225 [07:54<02:10,  2.61s/it]
# 카카오로도 해결할 수 없다.
#  79%|██████████████████████████████████████████████████████████████▉                 | 177/225 [07:58<01:58,  2.47s/it]
# 카카오로도 해결할 수 없다.
#  80%|████████████████████████████████████████████████████████████████▎               | 181/225 [08:09<02:03,  2.80s/it]
# 카카오로도 해결할 수 없다.
#  84%|███████████████████████████████████████████████████████████████████▏            | 189/225 [08:32<01:52,  3.12s/it]
# 카카오로도 해결할 수 없다.
#  85%|███████████████████████████████████████████████████████████████████▉            | 191/225 [08:37<01:32,  2.71s/it]
# 카카오로도 해결할 수 없다.
#  86%|████████████████████████████████████████████████████████████████████▌           | 193/225 [08:41<01:19,  2.50s/it]
# 카카오로도 해결할 수 없다.
#  87%|█████████████████████████████████████████████████████████████████████▎          | 195/225 [08:45<01:12,  2.41s/it]
# 카카오로도 해결할 수 없다.
#  90%|███████████████████████████████████████████████████████████████████████▊        | 202/225 [09:05<01:10,  3.05s/it]
# 카카오로도 해결할 수 없다.
#  90%|████████████████████████████████████████████████████████████████████████▏       | 203/225 [09:06<00:54,  2.46s/it]
# 카카오로도 해결할 수 없다.
#  91%|████████████████████████████████████████████████████████████████████████▉       | 205/225 [09:11<00:47,  2.39s/it]
# 카카오로도 해결할 수 없다.
#  92%|█████████████████████████████████████████████████████████████████████████▌      | 207/225 [09:15<00:42,  2.35s/it]
# 카카오로도 해결할 수 없다.
#  92%|█████████████████████████████████████████████████████████████████████████▉      | 208/225 [09:16<00:33,  1.97s/it]
# 카카오로도 해결할 수 없다.
#  93%|██████████████████████████████████████████████████████████████████████████▎     | 209/225 [09:17<00:27,  1.70s/it]
# 카카오로도 해결할 수 없다.
#  94%|███████████████████████████████████████████████████████████████████████████     | 211/225 [09:21<00:28,  2.01s/it]
# 카카오로도 해결할 수 없다.
#  99%|██████████████████████████████████████████████████████████████████████████████▉ | 222/225 [09:54<00:09,  3.16s/it]
# 카카오로도 해결할 수 없다.
# 100%|████████████████████████████████████████████████████████████████████████████████| 225/225 [10:02<00:00,  2.68s/it]
#      index                위치                도로명 포함 주소  \
# 0        7         우이제3교(북단)           우이천로 우이제3교(북단)
# 1       21     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2       37            암사정수센터              아리수로 암사정수센터
# 3       39           한국방송공사앞             여의서로 한국방송공사앞
# 4       44            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...
# 220   3130            잠실3삼거리               삼전로 잠실3삼거리
# 221   3132            대방천사거리              대방천로 대방천사거리
# 222   1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    663            북한남삼거리              이태원로 북한남삼거리
# 224   1475            북한남삼거리              한남대로 북한남삼거리
#
#                           url long lat
# 0    http://kko.to/u8zRmeRQJd
# 1    http://kko.to/StbHDfgnFN
# 2    http://kko.to/dn_Gnm85oJ
# 3    http://kko.to/yzK_6dH2ww
# 4    http://kko.to/9GQduBLMEA
# ..                        ...  ...  ..
# 220  http://kko.to/yNPtksQ8qu
# 221  http://kko.to/iG5tEPnxmM
# 222
# 223  http://kko.to/ELeVBpiUyE
# 224  http://kko.to/ELeVBpiUyE
#
# [225 rows x 6 columns]

# %%
result_reset_inext_2
# Out:
#      index                위치                도로명 포함 주소  \
# 0        7         우이제3교(북단)           우이천로 우이제3교(북단)
# 1       21     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2       37            암사정수센터              아리수로 암사정수센터
# 3       39           한국방송공사앞             여의서로 한국방송공사앞
# 4       44            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...
# 220   3130            잠실3삼거리               삼전로 잠실3삼거리
# 221   3132            대방천사거리              대방천로 대방천사거리
# 222   1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    663            북한남삼거리              이태원로 북한남삼거리
# 224   1475            북한남삼거리              한남대로 북한남삼거리
#
#                           url long lat  실패인덱스  실패_인덱스  실패___인덱스
# 0    http://kko.to/u8zRmeRQJd               7       7         7
# 1    http://kko.to/StbHDfgnFN              21      21        21
# 2    http://kko.to/dn_Gnm85oJ              37      37        37
# 3    http://kko.to/yzK_6dH2ww              39      39        39
# 4    http://kko.to/9GQduBLMEA              44      44        44
# ..                        ...  ...  ..    ...     ...       ...
# 220  http://kko.to/yNPtksQ8qu            3130    3130      3130
# 221  http://kko.to/iG5tEPnxmM            3132    3132      3132
# 222                                      1875    1875      1875
# 223  http://kko.to/ELeVBpiUyE             663     663       663
# 224  http://kko.to/ELeVBpiUyE            1475    1475      1475
#
# [225 rows x 9 columns]

# %%
result_reset_inext_3 = result_reset_inext_2
result_reset_inext_3
# Out:
#      index                위치                도로명 포함 주소  \
# 0        7         우이제3교(북단)           우이천로 우이제3교(북단)
# 1       21     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2       37            암사정수센터              아리수로 암사정수센터
# 3       39           한국방송공사앞             여의서로 한국방송공사앞
# 4       44            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...
# 220   3130            잠실3삼거리               삼전로 잠실3삼거리
# 221   3132            대방천사거리              대방천로 대방천사거리
# 222   1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    663            북한남삼거리              이태원로 북한남삼거리
# 224   1475            북한남삼거리              한남대로 북한남삼거리
#
#                           url long lat  실패인덱스  실패_인덱스  실패___인덱스
# 0    http://kko.to/u8zRmeRQJd               7       7         7
# 1    http://kko.to/StbHDfgnFN              21      21        21
# 2    http://kko.to/dn_Gnm85oJ              37      37        37
# 3    http://kko.to/yzK_6dH2ww              39      39        39
# 4    http://kko.to/9GQduBLMEA              44      44        44
# ..                        ...  ...  ..    ...     ...       ...
# 220  http://kko.to/yNPtksQ8qu            3130    3130      3130
# 221  http://kko.to/iG5tEPnxmM            3132    3132      3132
# 222                                      1875    1875      1875
# 223  http://kko.to/ELeVBpiUyE             663     663       663
# 224  http://kko.to/ELeVBpiUyE            1475    1475      1475
#
# [225 rows x 9 columns]

# %%
result_reset_inext_3["실패_인덱스"] = result_reset_inext_3["index"]
result_reset_inext_3
# Out:
#      index                위치                도로명 포함 주소  \
# 0        7         우이제3교(북단)           우이천로 우이제3교(북단)
# 1       21     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2       37            암사정수센터              아리수로 암사정수센터
# 3       39           한국방송공사앞             여의서로 한국방송공사앞
# 4       44            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...
# 220   3130            잠실3삼거리               삼전로 잠실3삼거리
# 221   3132            대방천사거리              대방천로 대방천사거리
# 222   1875  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    663            북한남삼거리              이태원로 북한남삼거리
# 224   1475            북한남삼거리              한남대로 북한남삼거리
#
#                           url long lat  실패인덱스  실패_인덱스  실패___인덱스
# 0    http://kko.to/u8zRmeRQJd               7       7         7
# 1    http://kko.to/StbHDfgnFN              21      21        21
# 2    http://kko.to/dn_Gnm85oJ              37      37        37
# 3    http://kko.to/yzK_6dH2ww              39      39        39
# 4    http://kko.to/9GQduBLMEA              44      44        44
# ..                        ...  ...  ..    ...     ...       ...
# 220  http://kko.to/yNPtksQ8qu            3130    3130      3130
# 221  http://kko.to/iG5tEPnxmM            3132    3132      3132
# 222                                      1875    1875      1875
# 223  http://kko.to/ELeVBpiUyE             663     663       663
# 224  http://kko.to/ELeVBpiUyE            1475    1475      1475
#
# [225 rows x 9 columns]

# %%
result_reset_inext_3 = result_reset_inext_3.drop(['index', '실패인덱스', '실패___인덱스'], axis=1)
result_reset_inext_3
# Out:
#                    위치                도로명 포함 주소                       url long  \
# 0           우이제3교(북단)           우이천로 우이제3교(북단)  http://kko.to/u8zRmeRQJd
# 1       홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)  http://kko.to/StbHDfgnFN
# 2              암사정수센터              아리수로 암사정수센터  http://kko.to/dn_Gnm85oJ
# 3             한국방송공사앞             여의서로 한국방송공사앞  http://kko.to/yzK_6dH2ww
# 4              여의하류IC               노들로 여의하류IC  http://kko.to/9GQduBLMEA
# ..                ...                      ...                       ...  ...
# 220            잠실3삼거리               삼전로 잠실3삼거리  http://kko.to/yNPtksQ8qu
# 221            대방천사거리              대방천로 대방천사거리  http://kko.to/iG5tEPnxmM
# 222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223            북한남삼거리              이태원로 북한남삼거리  http://kko.to/ELeVBpiUyE
# 224            북한남삼거리              한남대로 북한남삼거리  http://kko.to/ELeVBpiUyE
#
#     lat  실패_인덱스
# 0             7
# 1            21
# 2            37
# 3            39
# 4            44
# ..   ..     ...
# 220        3130
# 221        3132
# 222        1875
# 223         663
# 224        1475
#
# [225 rows x 6 columns]

# %%
result_reset_inext_3 = result_reset_inext_3.reset_index()
result_reset_inext_3
# Out:
#      index                위치                도로명 포함 주소  \
# 0        0         우이제3교(북단)           우이천로 우이제3교(북단)
# 1        1     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2        2            암사정수센터              아리수로 암사정수센터
# 3        3           한국방송공사앞             여의서로 한국방송공사앞
# 4        4            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...
# 220    220            잠실3삼거리               삼전로 잠실3삼거리
# 221    221            대방천사거리              대방천로 대방천사거리
# 222    222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    223            북한남삼거리              이태원로 북한남삼거리
# 224    224            북한남삼거리              한남대로 북한남삼거리
#
#                           url long lat  실패_인덱스
# 0    http://kko.to/u8zRmeRQJd                7
# 1    http://kko.to/StbHDfgnFN               21
# 2    http://kko.to/dn_Gnm85oJ               37
# 3    http://kko.to/yzK_6dH2ww               39
# 4    http://kko.to/9GQduBLMEA               44
# ..                        ...  ...  ..     ...
# 220  http://kko.to/yNPtksQ8qu             3130
# 221  http://kko.to/iG5tEPnxmM             3132
# 222                                       1875
# 223  http://kko.to/ELeVBpiUyE              663
# 224  http://kko.to/ELeVBpiUyE             1475
#
# [225 rows x 7 columns]

# %%
fail_list_kakao = pd.DataFrame({'실패인덱스':fail_index})
fail_list_kakao
# Out:
#     실패인덱스
# 0       5
# 1       7
# 2       8
# 3      10
# 4      13
# ..    ...
# 56    207
# 57    208
# 58    209
# 59    211
# 60    222
#
# [61 rows x 1 columns]

# %%
merge_left = pd.merge(fail_list_kakao,result_reset_inext_3, how='right', left_on='실패인덱스', right_on='index')
merge_left
# Out:
#      실패인덱스  index                위치                도로명 포함 주소  \
# 0      NaN      0         우이제3교(북단)           우이천로 우이제3교(북단)
# 1      NaN      1     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2      NaN      2            암사정수센터              아리수로 암사정수센터
# 3      NaN      3           한국방송공사앞             여의서로 한국방송공사앞
# 4      NaN      4            여의하류IC               노들로 여의하류IC
# ..     ...    ...               ...                      ...
# 220    NaN    220            잠실3삼거리               삼전로 잠실3삼거리
# 221    NaN    221            대방천사거리              대방천로 대방천사거리
# 222  222.0    222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    NaN    223            북한남삼거리              이태원로 북한남삼거리
# 224    NaN    224            북한남삼거리              한남대로 북한남삼거리
#
#                           url long lat  실패_인덱스
# 0    http://kko.to/u8zRmeRQJd                7
# 1    http://kko.to/StbHDfgnFN               21
# 2    http://kko.to/dn_Gnm85oJ               37
# 3    http://kko.to/yzK_6dH2ww               39
# 4    http://kko.to/9GQduBLMEA               44
# ..                        ...  ...  ..     ...
# 220  http://kko.to/yNPtksQ8qu             3130
# 221  http://kko.to/iG5tEPnxmM             3132
# 222                                       1875
# 223  http://kko.to/ELeVBpiUyE              663
# 224  http://kko.to/ELeVBpiUyE             1475
#
# [225 rows x 8 columns]

# %%
df = merge_left.dropna()
df
# Out:
#      실패인덱스  index                위치                도로명 포함 주소 url long lat  \
# 5      5.0      5               안양교               서부간선도로 안양교
# 7      7.0      7             이화교동단               중랑천로 이화교동단
# 8      8.0      8             오금교동측             서부간선도로 오금교동측
# 10    10.0     10      올림픽대로동부간선분기점    테헤란로115길 올림픽대로동부간선분기점
# 13    13.0     13             워베스빌앞             목동중앙본로 워베스빌앞
# ..     ...    ...               ...                      ...  ..  ...  ..
# 207  207.0    207            뚝섬정수장앞              강변북로 뚝섬정수장앞
# 208  208.0    208              선암UD               강남순환로 선암UD
# 209  209.0    209       올림픽대로동부간선JC        올림픽대로 올림픽대로동부간선JC
# 211  211.0    211            수출입은행뒤               은행로 수출입은행뒤
# 222  222.0    222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
#
#      실패_인덱스
# 5        46
# 7        58
# 8        71
# 10       89
# 13      132
# ..      ...
# 207    2931
# 208    2940
# 209    2955
# 211    3023
# 222    1875
#
# [61 rows x 8 columns]

# %%
result_reset_inext_3
# Out:
#      index                위치                도로명 포함 주소  \
# 0        0         우이제3교(북단)           우이천로 우이제3교(북단)
# 1        1     홍은램프진입(내부순환로)      내부순환로 홍은램프진입(내부순환로)
# 2        2            암사정수센터              아리수로 암사정수센터
# 3        3           한국방송공사앞             여의서로 한국방송공사앞
# 4        4            여의하류IC               노들로 여의하류IC
# ..     ...               ...                      ...
# 220    220            잠실3삼거리               삼전로 잠실3삼거리
# 221    221            대방천사거리              대방천로 대방천사거리
# 222    222  동부간선도로-일반국도6호선램프  동부간선도로 동부간선도로-일반국도6호선램프
# 223    223            북한남삼거리              이태원로 북한남삼거리
# 224    224            북한남삼거리              한남대로 북한남삼거리
#
#                           url long lat  실패_인덱스
# 0    http://kko.to/u8zRmeRQJd                7
# 1    http://kko.to/StbHDfgnFN               21
# 2    http://kko.to/dn_Gnm85oJ               37
# 3    http://kko.to/yzK_6dH2ww               39
# 4    http://kko.to/9GQduBLMEA               44
# ..                        ...  ...  ..     ...
# 220  http://kko.to/yNPtksQ8qu             3130
# 221  http://kko.to/iG5tEPnxmM             3132
# 222                                       1875
# 223  http://kko.to/ELeVBpiUyE              663
# 224  http://kko.to/ELeVBpiUyE             1475
#
# [225 rows x 7 columns]

# %%
result_reset_inext_3.to_csv('./카카오결과_1차.csv', encoding='EUC-KR')

# %%
df.to_csv('./카카오에서도실패.csv', encoding='EUC-KR')
