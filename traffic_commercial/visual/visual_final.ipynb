# %%
import pandas as pd
import seaborn as sns

# %%
big = pd.read_csv('./대형상권 2019~2022년 통계.csv')
very_big = pd.read_csv('./특대형상권 2019~2022년 통계.csv')
middle = pd.read_csv('./중형상권 2019~2022년 통계.csv')

# %%
middle
# Out:
#      index                상권_코드_명  점포_수    분기당_매출_금액  분기당_매출_건수        long  \
# 0      404                    인사동  1176  36548709173    1523915  126.985306
# 1      582                   인현시장   121   4778224891     160349  126.995031
# 2      713  사당1동먹자골목상점가(사당1동먹자골목)   229  12594278677     477494  126.980339
# 3      660          신촌 상인회(신촌상점가)    42   5847412477     320765  126.937177
# 4      515                사당역(사당)   965  58465103344    2471478  126.982522
# ..     ...                    ...   ...          ...        ...         ...
# 249    544              왕십리도선동상점가   414  16343808132     628835  127.034114
# 250    284              서울대입구역 8번   161   2287552989     174729  126.957907
# 251    508                동대문상가D동    47    905480866      16019  127.014647
# 252    183                 신촌역 6번    26    708917234      42972  126.938956
# 253    575                 강북북부시장    23   1506035529      81848  127.030431
#
#            lat          유동인구  환승가능한버스노선  500m 버스정류장  환승가능지하철         환승가능 호선명  \
# 0    37.573790  99194.048387   5.320000          25        2          1호선;3호선
# 1    37.563303  99024.983871   6.666667          12        4  4호선;2호선;3호선;5호선
# 2    37.478571  97066.645161   6.062500          16        2          4호선;2호선
# 3    37.556475  95352.741935   6.578947          38        2        경의중앙선;2호선
# 4    37.476139  94651.403226   4.590909          22        2          4호선;2호선
# ..         ...           ...        ...         ...      ...              ...
# 249  37.564127  64006.790323   3.892857          28        3      2호선;경원선;5호선
# 250  37.481935  63223.032258   4.909091          22        1              2호선
# 251  37.570006  63190.161290   4.111111          18        3      1호선;4호선;6호선
# 252  37.553404  63175.387097   5.821429          28        2        경의중앙선;2호선
# 253  37.636298  63130.564516   3.694444          36        1              4호선
#
#      500m 지하철역  상권규모  상권의 도로 평균 속도    연도
# 0            2  중형상권     17.430221  2019
# 1            3  중형상권     19.239769  2019
# 2            1  중형상권     26.153125  2019
# 3            1  중형상권     22.278036  2019
# 4            1  중형상권     28.914167  2019
# ..         ...   ...           ...   ...
# 249          2  중형상권     28.092738  2022
# 250          1  중형상권     21.898214  2022
# 251          2  중형상권     16.119402  2022
# 252          2  중형상권     22.899792  2022
# 253          1  중형상권     20.465625  2022
#
# [254 rows x 16 columns]

# %%
big.head()
# Out:
#    index      상권_코드_명  점포_수     분기당_매출_금액  분기당_매출_건수        long        lat  \
# 0      0     이태원 관광특구  1720  102083170176    4441275  126.994377  37.534435
# 1      3   종로?청계 관광특구  5552  172469071750    6280385  126.997374  37.569998
# 2    405        종로3가역  4040  129859262246    4114431  126.990921  37.572763
# 3    433  용산전자상가(용산역)  3630  522626656771    3105298  126.961148  37.533294
# 4    434    신용산역(용산역)  1458   93836541467    4625438  126.963368  37.527924
#
#            유동인구  환승가능한버스노선  500m 버스정류장  환승가능지하철     환승가능 호선명  500m 지하철역  상권규모  \
# 0  30909.564516   1.904762          21        1          6호선          1  대형상권
# 1  69533.048387   5.160000          25        3  1호선;2호선;5호선          2  대형상권
# 2  85810.758065   8.466667          15        3  1호선;3호선;5호선          1  대형상권
# 3  53583.677419   2.600000          25        1          1호선          1  대형상권
# 4  78287.580645   6.071429          14        2      1호선;4호선          2  대형상권
#
#    상권의 도로 평균 속도    연도
# 0     22.534167  2019
# 1     18.655153  2019
# 2     15.889688  2019
# 3     25.418807  2019
# 4     25.676071  2019

# %%
# <한글 문제 해결 코드>
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothicCoding')
# Troubleshooting -마이너스가 깨질 경우가 있음. 이 경우 아래 코드 추가
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus']=False

# %%
big = big[['상권_코드_명','상권규모', '연도', '유동인구', '분기당_매출_건수',  '분기당_매출_금액', '환승가능한버스노선', '500m 버스정류장', '환승가능지하철', '환승가능 호선명',  '500m 지하철역', '상권의 도로 평균 속도']]
very_big  = very_big[['상권_코드_명','상권규모', '연도', '유동인구', '분기당_매출_건수', '분기당_매출_금액', '환승가능한버스노선', '500m 버스정류장', '환승가능지하철', '환승가능 호선명',  '500m 지하철역', '상권의 도로 평균 속도']]
middle = middle[['상권_코드_명','상권규모', '연도', '유동인구', '분기당_매출_건수', '분기당_매출_금액', '환승가능한버스노선', '500m 버스정류장', '환승가능지하철', '환승가능 호선명',  '500m 지하철역', '상권의 도로 평균 속도']]
big
# Out:
#            상권_코드_명  상권규모    연도          유동인구  분기당_매출_건수     분기당_매출_금액  \
# 0         이태원 관광특구  대형상권  2019  30909.564516    4441275  102083170176
# 1       종로?청계 관광특구  대형상권  2019  69533.048387    6280385  172469071750
# 2            종로3가역  대형상권  2019  85810.758065    4114431  129859262246
# 3      용산전자상가(용산역)  대형상권  2019  53583.677419    3105298  522626656771
# 4        신용산역(용산역)  대형상권  2019  78287.580645    4625438   93836541467
# ..             ...   ...   ...           ...        ...           ...
# 127      잠실새내역(신천)  대형상권  2022  32798.306452    5140878  130030687992
# 128            천호역  대형상권  2022  45220.919355    4747990   97426198846
# 129    남대문시장(자유상가)  대형상권  2022  48276.048387    3407664  130246045600
# 130        청량리종합시장  대형상권  2022  32602.516129    4397975  125357966231
# 131  영등포청과시장(조광시장)  대형상권  2022  23107.209677    1787412  114742302130
#
#      환승가능한버스노선  500m 버스정류장  환승가능지하철     환승가능 호선명  500m 지하철역  상권의 도로 평균 속도
# 0     1.904762          21        1          6호선          1     22.534167
# 1     5.160000          25        3  1호선;2호선;5호선          2     18.655153
# 2     8.466667          15        3  1호선;3호선;5호선          1     15.889688
# 3     2.600000          25        1          1호선          1     25.418807
# 4     6.071429          14        2      1호선;4호선          2     25.676071
# ..         ...         ...      ...          ...        ...           ...
# 127  10.000000          11        1          2호선          1     24.340125
# 128   3.466667          15        2      8호선;5호선          1     22.443864
# 129   7.296296          27        1          4호선          1     21.148939
# 130   8.826087          23        0          NaN          0     16.603182
# 131   4.476190          21        1          5호선          1     18.477609
#
# [132 rows x 12 columns]

# %%
very_big
# Out:
#                    상권_코드_명   상권규모    연도           유동인구  분기당_매출_건수  \
# 0   명동 남대문 북창동 다동 무교동 관광특구  특대형상권  2019  138946.870968   16655824
# 1             동대문패션타운 관광특구  특대형상권  2019  107866.096774    6077340
# 2              강남 마이스 관광특구  특대형상권  2019  101897.145161    4768635
# 3                      종각역  특대형상권  2019  128279.516129    5696212
# 4                 명동(명동거리)  특대형상권  2019  124712.451613    8307033
# 5                영등포역(영등포)  특대형상권  2019  101130.467742    5724102
# 6            고속터미널(고속터미널역)  특대형상권  2019  122182.290323    5960050
# 7                      강남역  특대형상권  2019  137186.322581   15386089
# 8                      잠실역  특대형상권  2019  135727.838710    6910685
# 9          평화시장(통일상가 동화상가)  특대형상권  2019  139868.596774    1852188
# 10  명동 남대문 북창동 다동 무교동 관광특구  특대형상권  2022  111583.354839   15035663
# 11                     종각역  특대형상권  2022  100588.774194    4925993
# 12           고속터미널(고속터미널역)  특대형상권  2022  100292.580645    3617885
# 13         평화시장(통일상가 동화상가)  특대형상권  2022  103006.274194    3254288
#
#        분기당_매출_금액  환승가능한버스노선  500m 버스정류장  환승가능지하철         환승가능 호선명  500m 지하철역  \
# 0   392306973005   9.555556          18        2          1호선;2호선          2
# 1   204760984791   5.473684          19        4  1호선;4호선;2호선;5호선          2
# 2   173926103805   5.818182          22        2          9호선;2호선          2
# 3   133283055803   7.913043          23        2          1호선;2호선          2
# 4   164980548089   8.500000          16        2          4호선;2호선          2
# 5   135297169719   6.130435          23        2          1호선;5호선          2
# 6   115622138422   3.705882          17        3      7호선;3호선;9호선          1
# 7   369030668051   4.964286          28        1              2호선          1
# 8   106979893837   7.500000          12        2          8호선;2호선          1
# 9   116742115407   6.136364          22        4  1호선;4호선;2호선;5호선          3
# 10  414295939101   9.157895          19        2          1호선;2호선          2
# 11  129766749443   7.913043          23        2          1호선;2호선          2
# 12   99322681540   3.875000          16        3      7호선;3호선;9호선          1
# 13  106968434038   6.130435          23        4  1호선;4호선;5호선;2호선          3
#
#     상권의 도로 평균 속도
# 0      20.557020
# 1      16.466970
# 2      21.673906
# 3      15.925375
# 4      19.895342
# 5      19.562935
# 6      21.027045
# 7      19.547625
# 8      31.876484
# 9      18.701715
# 10     21.957649
# 11     15.974562
# 12     20.909432
# 13     18.685843

# %%
df= pd.concat([very_big, big, middle])
df.loc[df['상권규모'] == "특대형상권", '상권규모'] = "초대형상권"
df.head(30)
# Out:
#                    상권_코드_명   상권규모    연도           유동인구  분기당_매출_건수  \
# 0   명동 남대문 북창동 다동 무교동 관광특구  초대형상권  2019  138946.870968   16655824
# 1             동대문패션타운 관광특구  초대형상권  2019  107866.096774    6077340
# 2              강남 마이스 관광특구  초대형상권  2019  101897.145161    4768635
# 3                      종각역  초대형상권  2019  128279.516129    5696212
# 4                 명동(명동거리)  초대형상권  2019  124712.451613    8307033
# 5                영등포역(영등포)  초대형상권  2019  101130.467742    5724102
# 6            고속터미널(고속터미널역)  초대형상권  2019  122182.290323    5960050
# 7                      강남역  초대형상권  2019  137186.322581   15386089
# 8                      잠실역  초대형상권  2019  135727.838710    6910685
# 9          평화시장(통일상가 동화상가)  초대형상권  2019  139868.596774    1852188
# 10  명동 남대문 북창동 다동 무교동 관광특구  초대형상권  2022  111583.354839   15035663
# 11                     종각역  초대형상권  2022  100588.774194    4925993
# 12           고속터미널(고속터미널역)  초대형상권  2022  100292.580645    3617885
# 13         평화시장(통일상가 동화상가)  초대형상권  2022  103006.274194    3254288
# 0                 이태원 관광특구   대형상권  2019   30909.564516    4441275
# 1               종로?청계 관광특구   대형상권  2019   69533.048387    6280385
# 2                    종로3가역   대형상권  2019   85810.758065    4114431
# 3              용산전자상가(용산역)   대형상권  2019   53583.677419    3105298
# 4                신용산역(용산역)   대형상권  2019   78287.580645    4625438
# 5                이태원(이태원역)   대형상권  2019   28874.500000    4322545
# 6                건대입구역(건대)   대형상권  2019   78375.967742    5948602
# 7                      수유역   대형상권  2019   85964.564516    5849092
# 8                      노원역   대형상권  2019   68786.532258    5948498
# 9           신촌역(신촌역 신촌로터리)   대형상권  2019   95298.838710    7012973
# 10               홍대입구역(홍대)   대형상권  2019   22481.112903    7720666
# 11                 발산역(마곡)   대형상권  2019   31655.612903    3662170
# 12               여의도역(여의도)   대형상권  2019   68141.967742    6046300
# 13               노량진역(노량진)   대형상권  2019   75555.693548    8255341
# 14             교대역(법원.검찰청)   대형상권  2019   62187.758065    4986618
# 15                     신사역   대형상권  2019   51142.500000    3703225
#
#        분기당_매출_금액  환승가능한버스노선  500m 버스정류장  환승가능지하철         환승가능 호선명  500m 지하철역  \
# 0   392306973005   9.555556          18        2          1호선;2호선          2
# 1   204760984791   5.473684          19        4  1호선;4호선;2호선;5호선          2
# 2   173926103805   5.818182          22        2          9호선;2호선          2
# 3   133283055803   7.913043          23        2          1호선;2호선          2
# 4   164980548089   8.500000          16        2          4호선;2호선          2
# 5   135297169719   6.130435          23        2          1호선;5호선          2
# 6   115622138422   3.705882          17        3      7호선;3호선;9호선          1
# 7   369030668051   4.964286          28        1              2호선          1
# 8   106979893837   7.500000          12        2          8호선;2호선          1
# 9   116742115407   6.136364          22        4  1호선;4호선;2호선;5호선          3
# 10  414295939101   9.157895          19        2          1호선;2호선          2
# 11  129766749443   7.913043          23        2          1호선;2호선          2
# 12   99322681540   3.875000          16        3      7호선;3호선;9호선          1
# 13  106968434038   6.130435          23        4  1호선;4호선;5호선;2호선          3
# 0   102083170176   1.904762          21        1              6호선          1
# 1   172469071750   5.160000          25        3      1호선;2호선;5호선          2
# 2   129859262246   8.466667          15        3      1호선;3호선;5호선          1
# 3   522626656771   2.600000          25        1              1호선          1
# 4    93836541467   6.071429          14        2          1호선;4호선          2
# 5   101306831728   1.937500          16        1              6호선          1
# 6    98693168787   5.083333          12        2          7호선;2호선          1
# 7   100607911886   4.333333          42        1              4호선          1
# 8   124632362641   3.741935          31        2          4호선;7호선          1
# 9   121727081954   6.631579          38        2        경의중앙선;2호선          1
# 10  145452373703   2.882353          34        0              NaN          0
# 11   95346217764   5.235294          17        1              5호선          1
# 12  137924030885   8.461538          13        2          9호선;5호선          1
# 13  264212785679   7.611111          18        2          1호선;9호선          1
# 14  108646147779   2.823529          17        2          3호선;2호선          1
# 15  108977798760   7.333333           9        1              3호선          1
#
#     상권의 도로 평균 속도
# 0      20.557020
# 1      16.466970
# 2      21.673906
# 3      15.925375
# 4      19.895342
# 5      19.562935
# 6      21.027045
# 7      19.547625
# 8      31.876484
# 9      18.701715
# 10     21.957649
# 11     15.974562
# 12     20.909432
# 13     18.685843
# 0      22.534167
# 1      18.655153
# 2      15.889688
# 3      25.418807
# 4      25.676071
# 5      19.432188
# 6      20.036562
# 7      20.682386
# 8      22.100562
# 9      22.278036
# 10     17.116750
# 11     23.795625
# 12     23.105000
# 13     36.768056
# 14     20.166750
# 15     19.595625

# %%
sns.catplot(x="연도", y='분기당_매출_금액', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %% [markdown]
# # 상권의 규모와 분기당 매출 건수 비교

# %%
sns.catplot(x="연도", y='분기당_매출_건수', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %%
sns.catplot(x="연도", y='환승가능한버스노선', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %%
sns.catplot(x="연도", y='환승가능지하철', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %%
sns.catplot(x="연도", y='500m 버스정류장', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %% [markdown]
# # 상권의 규모와 500m범위 지하철역의 비교

# %%
sns.catplot(x="연도", y='500m 지하철역', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %%
sns.catplot(x="연도", y='500m 지하철역', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %%
sns.catplot(x="연도", y='500m 지하철역', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %%
sns.catplot(x="연도", y='유동인구', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %%
sns.catplot(x="연도", y='상권의 도로 평균 속도', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)

# %% [markdown]
# # 상권의 규모와 유동인의 평균속도 비교

# %%
sns.catplot(x="연도", y='유동인구', hue='상권규모', data=df, kind='bar', palette='muted', 
            legend=True, height=7)
