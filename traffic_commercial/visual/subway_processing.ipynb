# %%
import pandas as pd
sub_2022 = pd.read_csv('./metro_2019_10_location.csv', encoding='EUC-KR')
sub_2022
# Out:
#      Unnamed: 0     사용월    호선명      지하철역  출근시간(04~09) 승차  출근시간(07~10) 하차  \
# 0             0  201910    9호선        흑석           65143           62697
# 1             1  201910    6호선     효창공원앞           66258           43822
# 2             2  201910    경의선     효창공원앞           18808           24894
# 3             3  201910    4호선        회현           40413          305129
# 4             4  201910    경원선        회룡          180355           41343
# ..          ...     ...    ...       ...             ...             ...
# 432         432  201910    경부선   가산디지털단지           60879          170842
# 433         433  201910    7호선   가산디지털단지           78866          395297
# 434         434  201910    3호선      가락시장           77365           45275
# 435         435  201910    8호선      가락시장           41913           53410
# 436         436  201910  우이신설선  4.19민주묘지           27133           19218
#
#      퇴근시간(16~20) 승차  퇴근시간(17~21) 하차    점심시간    저녁시간  늦은시간퇴근(20~02) 승차  \
# ...

# %%
sub_2022["호선명"].value_counts()
# Out:
# 5호선         50
# 2호선         50
# 7호선         48
# 6호선         38
# 3호선         34
# 4호선         26
# 9호선         25
# 경의선         21
# 경원선         19
# 8호선         17
# 분당선         15
# 9호선2~3단계    13
# 경부선         13
# 우이신설선       13
# 일산선         10
# 1호선         10
# 중앙선          9
# 경인선          9
# 경춘선          6
# 공항철도 1호선     6
# 과천선          5
# Name: 호선명, dtype: int64

# %%
sub_2022.loc[sub_2022['호선명'] == "과천선", '호선명'] = "4호선"

# %%
sub_2022["호선명"].value_counts()
# Out:
# 5호선         50
# 2호선         50
# 7호선         48
# 6호선         38
# 3호선         34
# 4호선         31
# 9호선         25
# 경의선         21
# 경원선         19
# 8호선         17
# 분당선         15
# 9호선2~3단계    13
# 경부선         13
# 우이신설선       13
# 일산선         10
# 1호선         10
# 중앙선          9
# 경인선          9
# 경춘선          6
# 공항철도 1호선     6
# Name: 호선명, dtype: int64

# %%
sub_2022.loc[sub_2022['호선명'] == "경인선", '호선명'] = "1호선"
sub_2022.loc[sub_2022['호선명'] == "경부선", '호선명'] = "1호선"

# %%
sub_2022["호선명"].value_counts()
# Out:
# 5호선         50
# 2호선         50
# 7호선         48
# 6호선         38
# 3호선         34
# 1호선         32
# 4호선         31
# 9호선         25
# 경의선         21
# 경원선         19
# 8호선         17
# 분당선         15
# 우이신설선       13
# 9호선2~3단계    13
# 일산선         10
# 중앙선          9
# 공항철도 1호선     6
# 경춘선          6
# Name: 호선명, dtype: int64

# %%
sub_2022.loc[sub_2022['호선명'] == "중앙선", '호선명'] = "경의중앙선"

# %%
sub_2022["호선명"].value_counts()
# Out:
# 5호선         50
# 2호선         50
# 7호선         48
# 6호선         38
# 3호선         34
# 1호선         32
# 4호선         31
# 9호선         25
# 경의선         21
# 경원선         19
# 8호선         17
# 분당선         15
# 우이신설선       13
# 9호선2~3단계    13
# 일산선         10
# 경의중앙선        9
# 공항철도 1호선     6
# 경춘선          6
# Name: 호선명, dtype: int64

# %%
sub_2022.loc[sub_2022['호선명'] == "9호선2~3단계", '호선명'] = "9호선"

# %%
sub_2022.loc[sub_2022['호선명'] == "경의선", '호선명'] = "경의중앙선"

# %%
sub_2022.loc[sub_2022['호선명'] == "일산선", '호선명'] = "3호선"

# %%
sub_2022["호선명"].value_counts()
# Out:
# 5호선         50
# 2호선         50
# 7호선         48
# 3호선         44
# 9호선         38
# 6호선         38
# 1호선         32
# 4호선         31
# 경의중앙선       30
# 경원선         19
# 8호선         17
# 분당선         15
# 우이신설선       13
# 공항철도 1호선     6
# 경춘선          6
# Name: 호선명, dtype: int64

# %%
sub_2022.to_csv('./metro_2019_10_location.csv', encoding='EUC-KR', index=False)
sub_2022
# Out:
#      Unnamed: 0     사용월    호선명      지하철역  출근시간(04~09) 승차  출근시간(07~10) 하차  \
# 0             0  201910    9호선        흑석           65143           62697
# 1             1  201910    6호선     효창공원앞           66258           43822
# 2             2  201910  경의중앙선     효창공원앞           18808           24894
# 3             3  201910    4호선        회현           40413          305129
# 4             4  201910    경원선        회룡          180355           41343
# ..          ...     ...    ...       ...             ...             ...
# 432         432  201910    1호선   가산디지털단지           60879          170842
# 433         433  201910    7호선   가산디지털단지           78866          395297
# 434         434  201910    3호선      가락시장           77365           45275
# 435         435  201910    8호선      가락시장           41913           53410
# 436         436  201910  우이신설선  4.19민주묘지           27133           19218
#
#      퇴근시간(16~20) 승차  퇴근시간(17~21) 하차    점심시간    저녁시간  늦은시간퇴근(20~02) 승차  \
# ...
