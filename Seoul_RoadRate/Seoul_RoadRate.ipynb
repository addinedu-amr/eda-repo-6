# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
Seoul_Road = pd.read_csv('./Roadrate.csv')

Seoul_Road.head()
# Out:
#    자치구별(1)  자치구별(2)       2015    2015.1   2015.2       2016    2016.1  \
# 0  자치구별(1)  자치구별(2)  도로연장 (km)  도로면적 (㎢)  도로율 (%)  도로연장 (km)  도로면적 (㎢)
# 1       합계       소계       8215     84.00    22.43       8241     84.88
# 2       합계      종로구        274      2.67    21.19        275      2.67
# 3       합계       중구        114      1.88    18.82        114      1.88
# 4       합계      용산구        280      3.14    22.11        280      3.14
#
#     2016.2       2017    2017.1  ...   2018.2       2019    2019.1   2019.2  \
# 0  도로율 (%)  도로연장 (km)  도로면적 (㎢)  ...  도로율 (%)  도로연장 (km)  도로면적 (㎢)  도로율 (%)
# 1    22.66       8271     86.00  ...    22.72       8310     86.86    22.94
# 2    21.20        275      2.68  ...    21.34        275      2.69    21.34
# 3    18.82        114      1.88  ...    18.82        114      1.88    18.82
# 4    22.06        281      3.15  ...    22.15        281      3.15    22.19
#
#         2020    2020.1   2020.2       2021    2021.1   2021.2
# 0  도로연장 (km)  도로면적 (㎢)  도로율 (%)  도로연장 (km)  도로면적 (㎢)  도로율 (%)
# 1       8324     86.06    23.05       8328     86.90    23.20
# 2        276      2.69    21.44        276      2.70    21.44
# 3        114      1.88    18.82        114      1.88    18.82
# 4        281      3.15    22.19        281      3.15    22.19
#
# [5 rows x 23 columns]

# %% [markdown]
# 도로율의 변화 추이를 알아보자

# %% [markdown]
# 연도별 도로 연장

# %%
Seoul_Road.columns
# Out:
# Index(['자치구별(1)', '자치구별(2)', '2015', '2015.1', '2015.2', '2016', '2016.1',
#        '2016.2', '2017', '2017.1', '2017.2', '2018', '2018.1', '2018.2',
#        '2019', '2019.1', '2019.2', '2020', '2020.1', '2020.2', '2021',
#        '2021.1', '2021.2'],
#       dtype='object')

# %%
for each in ['2015', '2016', '2017', '2018', '2019', '2020', '2021']:
    print(each + "도로연장")
# Out:
# 2015도로연장
# 2016도로연장
# 2017도로연장
# 2018도로연장
# 2019도로연장
# 2020도로연장
# 2021도로연장

# %%
for each in ['2015', '2016', '2017', '2018', '2019', '2020', '2021']:
    Seoul_Road.rename(columns={               
                    each : each + "_도로연장",
                    each+".1": each + '_도로면적',
                    each+".2": each + '_도로율'},inplace=True)

# %%
Seoul_Road.rename(columns={'자치구별(2)':'구'}, inplace=True)

# %%
Seoul_Road.head()
# Out:
#    자치구별(1)        구  2015_도로연장 2015_도로면적 2015_도로율  2016_도로연장 2016_도로면적  \
# 0  자치구별(1)  자치구별(2)  도로연장 (km)  도로면적 (㎢)  도로율 (%)  도로연장 (km)  도로면적 (㎢)
# 1       합계       소계       8215     84.00    22.43       8241     84.88
# 2       합계      종로구        274      2.67    21.19        275      2.67
# 3       합계       중구        114      1.88    18.82        114      1.88
# 4       합계      용산구        280      3.14    22.11        280      3.14
#
#   2016_도로율  2017_도로연장 2017_도로면적  ... 2018_도로율  2019_도로연장 2019_도로면적 2019_도로율  \
# 0  도로율 (%)  도로연장 (km)  도로면적 (㎢)  ...  도로율 (%)  도로연장 (km)  도로면적 (㎢)  도로율 (%)
# 1    22.66       8271     86.00  ...    22.72       8310     86.86    22.94
# 2    21.20        275      2.68  ...    21.34        275      2.69    21.34
# 3    18.82        114      1.88  ...    18.82        114      1.88    18.82
# 4    22.06        281      3.15  ...    22.15        281      3.15    22.19
#
#    2020_도로연장 2020_도로면적 2020_도로율  2021_도로연장 2021_도로면적 2021_도로율
# 0  도로연장 (km)  도로면적 (㎢)  도로율 (%)  도로연장 (km)  도로면적 (㎢)  도로율 (%)
# 1       8324     86.06    23.05       8328     86.90    23.20
# 2        276      2.69    21.44        276      2.70    21.44
# 3        114      1.88    18.82        114      1.88    18.82
# 4        281      3.15    22.19        281      3.15    22.19
#
# [5 rows x 23 columns]

# %%
Seoul_Road.drop([0,1],inplace=True)
Seoul_Road.head()
# Out:
#   자치구별(1)    구 2015_도로연장 2015_도로면적 2015_도로율 2016_도로연장 2016_도로면적 2016_도로율  \
# 2      합계  종로구       274      2.67    21.19       275      2.67    21.20
# 3      합계   중구       114      1.88    18.82       114      1.88    18.82
# 4      합계  용산구       280      3.14    22.11       280      3.14    22.06
# 5      합계  성동구       408      3.02    23.07       408      3.02    23.07
# 6      합계  광진구       324      3.39    28.44       324      3.39    28.44
#
#   2017_도로연장 2017_도로면적  ... 2018_도로율 2019_도로연장 2019_도로면적 2019_도로율 2020_도로연장  \
# 2       275      2.68  ...    21.34       275      2.69    21.34       276
# 3       114      1.88  ...    18.82       114      1.88    18.82       114
# 4       281      3.15  ...    22.15       281      3.15    22.19       281
# 5       408      3.02  ...    23.09       408      3.02    23.09       408
# 6       324      3.39  ...    28.50       325      3.44    28.83       325
#
#   2020_도로면적 2020_도로율 2021_도로연장 2021_도로면적 2021_도로율
# 2      2.69    21.44       276      2.70    21.44
# 3      1.88    18.82       114      1.88    18.82
# 4      3.15    22.19       281      3.15    22.19
# 5      3.02    23.09       408      3.02    23.09
# 6      3.40    28.83       325      3.44    28.83
#
# [5 rows x 23 columns]

# %%
Seoul_Road.set_index('구', inplace=True)

# %%
Seoul_Road.head()
# Out:
#     자치구별(1) 2015_도로연장 2015_도로면적 2015_도로율 2016_도로연장 2016_도로면적 2016_도로율  \
# 구
# 종로구      합계       274      2.67    21.19       275      2.67    21.20
# 중구       합계       114      1.88    18.82       114      1.88    18.82
# 용산구      합계       280      3.14    22.11       280      3.14    22.06
# 성동구      합계       408      3.02    23.07       408      3.02    23.07
# 광진구      합계       324      3.39    28.44       324      3.39    28.44
#
#     2017_도로연장 2017_도로면적 2017_도로율  ... 2018_도로율 2019_도로연장 2019_도로면적 2019_도로율  \
# 구                                 ...
# 종로구       275      2.68    21.31  ...    21.34       275      2.69    21.34
# 중구        114      1.88    18.82  ...    18.82       114      1.88    18.82
# 용산구       281      3.15    22.15  ...    22.15       281      3.15    22.19
# 성동구       408      3.02    23.07  ...    23.09       408      3.02    23.09
# 광진구       324      3.39    28.45  ...    28.50       325      3.44    28.83
#
#     2020_도로연장 2020_도로면적 2020_도로율 2021_도로연장 2021_도로면적 2021_도로율
# 구
# 종로구       276      2.69    21.44       276      2.70    21.44
# 중구        114      1.88    18.82       114      1.88    18.82
# 용산구       281      3.15    22.19       281      3.15    22.19
# 성동구       408      3.02    23.09       408      3.02    23.09
# 광진구       325      3.40    28.83       325      3.44    28.83
#
# [5 rows x 22 columns]

# %%
Road_Extension = Seoul_Road.iloc[:, [1,4,7,10,13,16,19]]
Road_Extension.head()
# Out:
#     2015_도로연장 2016_도로연장 2017_도로연장 2018_도로연장 2019_도로연장 2020_도로연장 2021_도로연장
# 구
# 종로구       274       275       275       275       275       276       276
# 중구        114       114       114       114       114       114       114
# 용산구       280       280       281       281       281       281       281
# 성동구       408       408       408       408       408       408       408
# 광진구       324       324       324       324       325       325       325

# %%
Road_Rate = Seoul_Road.iloc[:,[3,6,9,12,15,18,21]]
Road_Rate.head()
# Out:
#     2015_도로율 2016_도로율 2017_도로율 2018_도로율 2019_도로율 2020_도로율 2021_도로율
# 구
# 종로구    21.19    21.20    21.31    21.34    21.34    21.44    21.44
# 중구     18.82    18.82    18.82    18.82    18.82    18.82    18.82
# 용산구    22.11    22.06    22.15    22.15    22.19    22.19    22.19
# 성동구    23.07    23.07    23.07    23.09    23.09    23.09    23.09
# 광진구    28.44    28.44    28.45    28.50    28.83    28.83    28.83

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rc('font', family = 'NanumGothicCoding')

# %%
Road_Extension = Road_Extension.astype('int64')

# %%
plt.figure(figsize = (13,10))
sns.heatmap(Road_Extension, annot=True, linewidths = .5, cmap='RdPu')
plt.title('서울시 구별 도로 연장')
plt.autoscale()
plt.tight_layout(pad=5)
plt.show()

# %%
import json
import folium

# %%
geo_path = './skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))
my_map = folium.Map(location=[37.5502,126.982], zoom_start = 11, tiles='OpenStreetMap')
my_map.choropleth(
    geo_data=geo_str,
    data=Road_Extension['2021_도로연장'],
    columns=[Road_Extension.index, Road_Extension['2021_도로연장']],
    fill_color='PuRd',
    key_on="feature.id",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="구별 도로연장",
)
folium.GeoJson(
    geo_str,
    style_function = lambda x: {'fillColor':'#00000000',
    							'color':'black',
   							    'weight' :'2'}
).add_to(my_map)
# Out:
# /home/gwon/venv/dt_v/lib/python3.8/site-packages/folium/folium.py:407: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4febb054be623ba648a0b6a8a9a096f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4febb054be623ba648a0b6a8a9a096f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c4febb054be623ba648a0b6a8a9a096f = L.map(
#                 &quot;map_c4febb054be623ba648a0b6a8a9a096f&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0477a4305b39fbca40fa2ba2eca77e0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4febb054be623ba648a0b6a8a9a096f);
#
#
#             var choropleth_659e21bf3d8ff61f4b1929f3775491be = L.featureGroup(
#                 {}
#             ).addTo(map_c4febb054be623ba648a0b6a8a9a096f);
#
#
#         function geo_json_008cecb26e6a6c93d976fcf9e63e7201_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc131\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_008cecb26e6a6c93d976fcf9e63e7201_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_008cecb26e6a6c93d976fcf9e63e7201 = L.geoJson(null, {
#                 onEachFeature: geo_json_008cecb26e6a6c93d976fcf9e63e7201_onEachFeature,
#
#                 style: geo_json_008cecb26e6a6c93d976fcf9e63e7201_styler,
#         });
#
#         function geo_json_008cecb26e6a6c93d976fcf9e63e7201_add (data) {
#             geo_json_008cecb26e6a6c93d976fcf9e63e7201
#                 .addData(data)
#                 .addTo(choropleth_659e21bf3d8ff61f4b1929f3775491be);
#         }
#             geo_json_008cecb26e6a6c93d976fcf9e63e7201_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11240&quot;, &quot;name&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;

# %%
Road_Rate = Road_Rate.astype('float')

# %%
plt.figure(figsize = (13,10))
sns.heatmap(Road_Rate, annot=True, linewidths = .5, cmap='RdPu')
plt.title('서울시 구별 도로율 차이')
plt.autoscale()
plt.tight_layout(pad=5)
plt.show()

# %%
geo_path = './skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))
rate_map = folium.Map(location=[37.5502,126.982], zoom_start = 11, tiles='OpenStreetMap')
rate_map.choropleth(
    geo_data=geo_str,
    data=Road_Rate['2021_도로율'],
    columns=[Road_Rate.index, Road_Rate['2021_도로율']],
    fill_color='PuRd',
    key_on="feature.id",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="구별 도로율",
)
folium.GeoJson(
    geo_str,
    style_function = lambda x: {'fillColor':'#00000000',
    							'color':'black',
   							    'weight' :'2'}
).add_to(rate_map)
# Out:
# /home/gwon/venv/dt_v/lib/python3.8/site-packages/folium/folium.py:407: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(

# %%
rate_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77cf41e6ae2298c84c65eb3cf8545622 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77cf41e6ae2298c84c65eb3cf8545622&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_77cf41e6ae2298c84c65eb3cf8545622 = L.map(
#                 &quot;map_77cf41e6ae2298c84c65eb3cf8545622&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ec5682dcf68d89e38ece73c84faa932 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77cf41e6ae2298c84c65eb3cf8545622);
#
#
#             var choropleth_a60aa2cb28f008fdad07daf6e64c7e93 = L.featureGroup(
#                 {}
#             ).addTo(map_77cf41e6ae2298c84c65eb3cf8545622);
#
#
#         function geo_json_db9b64e72d052ea880f085913940728a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_db9b64e72d052ea880f085913940728a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_db9b64e72d052ea880f085913940728a = L.geoJson(null, {
#                 onEachFeature: geo_json_db9b64e72d052ea880f085913940728a_onEachFeature,
#
#                 style: geo_json_db9b64e72d052ea880f085913940728a_styler,
#         });
#
#         function geo_json_db9b64e72d052ea880f085913940728a_add (data) {
#             geo_json_db9b64e72d052ea880f085913940728a
#                 .addData(data)
#                 .addTo(choropleth_a60aa2cb28f008fdad07daf6e64c7e93);
#         }
#             geo_json_db9b64e72d052ea880f085913940728a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0
